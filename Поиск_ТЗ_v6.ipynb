# %% [markdown]
# Техническое задание содержится в файле
# Документация.rar\ч. V Техничесая часть.docx

# %% [markdown]
# # 1. Поиск ТЗ в списке документации к закупке

# %%
# pip install bayoo-docx
# pip install aspose-zip
# pip install aspose-words
# pip install pdfplumber #Работа с .PDF

import os, shutil, sys, re
from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph
import aspose.zip as az
import aspose.words as aw
import pdfplumber
import pandas as pd

def doc2txt(path):
    doc = aw.Document(path).get_text()
    s = re.sub('[\x07\x0b\x13HYPERLINK]', ' ', doc).split('\r')
    return '\n'.join([i.strip() for i in s if len(i.strip())>0][1:-1]) 

def zip2dir(fname):
    # Загрузить архив
    with az.Archive(fname) as archive:
	    # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def rar2dir(fname):
    # Загрузить архив
    with az.rar.RarArchive(fname) as archive:
        # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def iter_block_items(parent):
    """
    Generate a reference to each paragraph and table child within *parent*,
    in document order. Each returned value is an instance of either Table or
    Paragraph. *parent* would most commonly be a reference to a main
    Document object, but also works for a _Cell object, which itself can
    contain paragraphs and tables.
    """
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    elif isinstance(parent, _Row):
        parent_elm = parent._tr
    else:
        raise ValueError("something's not right")
    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

def docx2txt(docx_file):
    document = Document(docx_file)
    text = []
    for block in iter_block_items(document):
        #print(block.text if isinstance(block, Paragraph) else '<table>')
        if isinstance(block, Paragraph):
            if len(block.text.strip()) > 0:
                text.append(block.text)
        elif isinstance(block, Table):
            for row in block.rows:
                row_data = []
                for cell in row.cells:
                    for paragraph in cell.paragraphs:
                        row_data.append(paragraph.text)
                text.append("\t".join(row_data))    
    return '\n'.join(text)

def pdf2txt(fname):
    with pdfplumber.open(fname) as pdf:
        if len(pdf.pages):
            text_o = ' '.join([
                page.extract_text() or '' for page in pdf.pages if page
            ])
    return text_o

def xlsx2txt(fname):
    return pd.read_excel(fname).to_string()

def to_txt(path):
    txt_from_files = {}
    for root, dirs, files in os.walk(path):
        #print(f'{root=}, {dirs=}, {files=}')
        for fn in files:
            ext = fn.split('.')[-1]
            ffn = os.path.join(root, fn)
            if ext=='doc':
                txt_from_files[ffn] = doc2txt(ffn)
            elif ext=='docx':
                txt_from_files[ffn] = docx2txt(ffn)
            elif ext=='txt':
                with open(ffn,'r') as f:
                    txt_from_files[ffn] = f.read()
            elif ext in [ 'xlsx']:
                txt_from_files[ffn] = xlsx2txt(ffn)
            elif ext=='rar':
                rar2dir(ffn)
            elif ext=='zip':
                zip2dir(ffn)
    return txt_from_files

def clear_temp(path_temp):# Очистка временной папки
    if os.path.exists(path_temp): 
        shutil.rmtree(path_temp)
    os.mkdir(path_temp)

def find_nearest_file(texts, keywords):
    '''
    На вход подается словарь вида имя файла: текст и список ключевых фраз в формате re
    Функция ищет по ключевым фразам в тексте наиболее близкий по содержанию файл
    На выходе имя найденного файла 
    '''
    closest_file = None
    max_count = 0
    for filename, text in texts.items():
        if len(text)>0: 
            if sum([len(re.findall (k, os.path.basename(filename).lower())) for k in keywords]): # Если найдены совпадения в названии файла
                return filename
            else:
                text = re.sub("[^а-я\n ]", "", text.lower()).strip() # оставляем только русские буквы и перевод строки
                cnt = sum([len(re.findall (k, text)) for k in keywords])
                distance = 0
                text = text.split('\n')
                if cnt: # если найдено хоть одно совпадение
                    for i,s in enumerate(text): # то ищем номера строк в которых эти ключи найдены
                        cnt = sum([len(re.findall (k, s)) for k in keywords])
                        if cnt:
                            distance += cnt/(i+1) # вычисляем дистанцию, чем дальше фраза от начала документа, тем меньше ее вес
                    if distance > max_count:
                        max_count = distance
                        closest_file = filename
                print(f'{distance=:0.3f}, {filename=}')
                    
    return closest_file

# ==================================================================
path_root = "C:/temp/"
path_temp = "temp"
keywords = [r"\bтехническ.. задан*",  "описание объекта закупки"]

if  not os.path.exists(path_root):
    print("Папка не существует")
    sys.exit()

dirs = next(os.walk(path_root))[1]
# dirs = ['0124600003224000028']
for path in dirs:
    clear_temp(path_temp)
    path = os.path.join(path_root, path)    
    txt_from_files = to_txt(path)
    txt_from_arch = to_txt(path_temp)
    if txt_from_arch:
        txt_from_files = txt_from_files | txt_from_arch
    #clear_temp(path_temp)
    file_tz = find_nearest_file(txt_from_files, keywords)
    if file_tz:
        print(f'Техническое задание из каталога {path} с наибольшей вероятностью содержится в файле: {file_tz}')
        print(txt_from_files[file_tz][:200])
    else:
        print(f'Техническое задание из каталога {path} не найдено')
    print()

    
for key, value in txt_from_files.items():
    if len(value)!=0:
        fn = os.path.basename(key)
        fn = '.'.join(fn.split('.')[:-1]) +'.txt'
        with open(os.path.join(path_temp, fn), 'w', encoding='utf-8') as f:
            f.write(value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       1 # pip install bayoo-docx
#       2 # pip install aspose-zip
#       3 # pip install aspose-words
#       4 # pip install pdfplumber #Работа с .PDF
#       6 import os, shutil, sys, re
# ----> 7 from docx import Document
#       8 from docx.document import Document as _Document
#       9 from docx.oxml.text.paragraph import CT_P
#
# ModuleNotFoundError: No module named 'docx'

# %% [markdown]
# # Подсчет ключевых слов в тексте

# %%
import re

def search_keys(text, keys):
    '''
    Функция считает количество ключевых слов/фраз в тексте
    На входе - текст, список ключевых слов в виде списка фраз в формате regex
    На выходе - словарь с ключами и их количеством
    '''
    text =  text.lower().strip() # переводим в нижний регистр
    cnt= {l[0]:len(l) for k in keys if len(l:=re.findall(k, text))>0}       
    return cnt


neg_keys = [
    r"континент",
    r"техническая поддержка",
    r"абонемент",
    r"доработка",
    r"защита (информации)",
    r"консультации",
    r"консультационные услуги",
    r"образование",
    r"образовательные услуги",
    r"глонасс",
    r"gps",
    r"бюджет",
    r"антивирус",
    r"контур контур контур",
    r"(?:\bмис\b|медицинская информационная система)",
    r"мис ариадна",
    r"техэксперт",
    r"бд супа",
    r"технокад",
    r"omnicommonline",
    r"карант",
    r"парус",
    r"континент",
    r"оборудование",
    r"лицензия",
    r"неисключительные права",
    r"аттестация",
    r"контур-фокус",
    r"сертификат",
    r"брест",
    r"vipnet",
    r"барс-здравоохранение",
    r"бит.управление медицинскими сервисами",
    r"autosat",
    r"varonis",
    r"гранд-смета",
    r"спарк",
    r"кодекс",
    r"иас контрагент",
    r"катарсис",
    r"статус-поставщик",
    r"rosa",
    r"labforce",
    r"enterprize",
    r"vizualization",
    r"businessstudio",
    r"право использования"
    ]
pos_keys = [
    r"(?:созда|разработ)[а-я]{2,3} сайт\w*",
    r"(?:созда|разработ)[а-я]{2,3} мобильн[а-я]{2,3} приложени\w*",
    r"(?:созда|разработ)[а-я]{2,3} пользовательск[а-я]{2,3} интерфейс\w*",
    r"(?:созда|разработ)[а-я]{2,3} нейросет\w*",
    r"(?:созда|разработ)[а-я]{2,3} алгоритм\w* анализа данных",
    r"(?:созда|разработ)[а-я]{2,3} архитектур\w* приложен\w*",
    r"(?:созда|разработ)[а-я]{2,3} дашборд\w*",
    r"(?:созда|разработ)[а-я]{2,3} микросервис\w*",
    r"(?:созда|разработ)[а-я]{2,3} механизм\w* аутентификац\w*",
    r"интегрирова[а-я]{2,3} внешн[а-я]{2,3} сервис\w*",
    r"интегрирова[а-я]{2,3} систем\w? аналитики и мониторинг\w?",
    r"автоматиз[а-я]{4,7} бизнес-процесс",
    r"провести тестирование производительности и безопасности",
    r"оптимиз[а-я]{4,7} код\w*",
    r"оптимиз[а-я]{4,7} интерфейс\w*",
    r"оптимиз[а-я]{4,7} запрос\w*",
    r"развер[а-я]{4,7} приложени\w на сервер\w*",
    r"провести аудит и рефакторинг кода",
    r"емейл-маркетинг",
    r"автоматизация процессов",
    r"сопровождение портала",
    r"актуализация документации",
    r"информационное сопровождение",
    r"smm-сопровождение",
    r"обработка данных",
    r"размещение материалов",
    r"реклама",
    r"размещение информации",
    r"предоставление хостинга",
    r"мониторинг сми",
    r"контент",
    r"маркетинговые услуги",
    r"продвижение в социальных сетях",
    r"базы данных",
    r"аналитическое сопровождение",
    r"мониторинг",
    r"контент-маркетинг",
    r"веб-разработка",
    r"рекламные услуги",
    r"информационное обслуживание",
    r"информационная кампания",
    r"облачные сервисы",
    r"электронная база данных",
    r"мультимедийные услуги",
    r"анализ данных",
    r"сетевое издание",
    r"цифровой образовательный ресурс",
    r"модернизация сайтов",
    r"онлайн-продажи",
    r"искусственный интеллект",
    r"портал",
    r"автоматизация",
    r"сервис",
    r"информационная система",
    r"агрегатор",
    r"личный кабинет",
    r"онлайн",
    r"анализ",
    r"логотип",
    r"лэндинг сайт",
    r"ведение соцсетей",
    r"интернет магазин",
    r"промо-сайт",
    r"интеграция",
    r"сервис",
    r"интернет ресурс",
    r"естественная речь",
    r"естественный язык",
    r"машинное обучение",
    r"\bml\b",
    r"\bai\b",
    r"\bcrm\b",
    r"биг-дата",
    r"бигдата",
    r"интернет",
    r"компьютерное зрение",
    r"devops",
    r"данные",
    r"разработка",
    r"приложение",
    r"фронтенд",
    r"бэкенд",
    r"маркетинг",
    r"веб-сервисы",
    r"веб-аналитика"
    ]

with open(r'/mnt/c/temp/z32413301283/ч. V Техничесая часть.txt', 'r') as f: # , encoding='utf-8'
    text = f.read()
pos_cnt = search_keys(text, pos_keys)
neg_cnt = search_keys(text, neg_keys)
print(f'Всего слов-маркеров {sum(pos_cnt.values())}:')
print(*[f'{k}({v})' for k,v in pos_cnt.items()], sep=', ')
print(f'Всего стоп-слов {sum(neg_cnt.values())}:')
print(*[f'{k}({v})' for k,v in neg_cnt.items()], sep=', ')

# %%
# Классификация по теме закупки

# %%
import pandas as pd
import re

def search_keys(text, keys):
    '''
    Функция считает количество ключевых слов/фраз в тексте
    На входе - текст, список ключевых слов в виде списка фраз в формате regex
    На выходе - словарь с ключами и их количеством
    '''
    text =  text.lower().strip() # переводим в нижний регистр
    text = ' '.join(text.split()) # удаляем двойные пробелы
    cnt= {l[0]:len(l) for k in keys if len(l:=re.findall(k.lower(), text))>0}       
    return cnt

work_class = {
    0:'Веб-разработка',
    1:'Дизайн',
    2:'Маркетинг',
    3:'Системный и бизнес анализ',
    4:'Тестирование',
    5:'Data science',
    6:'Беспилотники'
}
work_role = {
    0:'Подходит СОЮЗу',
    1:'Подходит СОЮЗу с поддержкой 1Т',
    2:'Не подходит СОЮЗу'
}

df_keys = pd.read_csv('key_words.csv',delimiter=';')
df_db = pd.read_csv('/mnt/c/temp/df_pp_stem_lemm.csv')
# df_db[df_db.sentiment!=0].loc[:,['sentiment','name']]
db = []
for idx,row in df_db.iterrows():
    db.append({}) 
    # Находим индекс последнего элемента
    li = len(db) - 1
    db[li]['target']=row['sentiment']
    db[li]['name_z']=row['name']
    db[li]['neg_keys']=[]
    db[li]['pos_keys']=[]
    # Negative keys
    keys = df_keys[(df_keys.np==0)].key.to_list()
    text =  row['name'].lower().strip() # переводим в нижний регистр
    cnt = search_keys(text, keys) 
    if len(cnt) > 0:
        db[li]['neg_keys'].append(cnt)
    # Positive keys
    for dest in df_keys[df_keys.np==1].dest.unique():
        for cl in df_keys[(df_keys.np==1) & (df_keys.dest==dest)].cls.unique():
            keys = df_keys[(df_keys.np==1) & (df_keys.dest==dest) & (df_keys.cls==cl)].key.to_list()
            text =  row['name'].lower().strip() # переводим в нижний регистр
            cnt = search_keys(text, keys) 
            if len(cnt) > 0:
                db[li]['pos_keys'].append(cnt)

neg_o=0
for d  in db:
    if  not (len(d['pos_keys'])==0 and len(d['neg_keys'])>0 and d['target']==0):
        print(d['target'], d['name_z'])
        print('Pos', d['pos_keys'], 'Neg', d['neg_keys'])
    else:
        neg_o += 1
print(len(db),neg_o)
# Out:
# 0 	Модернизация процессов управления автоматизированной системой диспетчерской службы скорой медицинской помощи, необходимые для создания структурированного электронного документа
# Pos [] Neg []
# 0 14_Оказание услуг в области информационных технологий по продлению неисключительных (пользовательских) лицензионных прав электронной базы данных «Госфинансы»
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'продлени': 1}]
# 0 № зз-34245-2023 Программное обеспечение, предназначенное для защиты приложений от несанкционированного доступа
# Pos [] Neg []
# 0 Автоматизация процессов работы лаборатории
# Pos [{'автоматизация процессов': 1, 'автоматизация': 1}] Neg []
# 0 Выбор Подрядчика на выполнение обязательств по монтажу видеонаблюдения, согласно сметному расчету, технического задания в МАУ «Центр культуры и досуга г. Улан-Удэ» по адресу: Республика Бурятия, г. Улан-Удэ, ул. Бабушкина 7. (цокольный этаж)
# Pos [] Neg []
# 0 Выполнение работ по диспетчеризации и автоматизация котельной №7 с.Муслюмово
# Pos [{'автоматизация': 1}] Neg [{'диспетчеризац': 1}]
# 0 Выполнение работ по обслуживанию мультимедийного оборудования
# Pos [{'мультимеди': 1}] Neg [{'работ по обслуживан': 1}]
# 0 Выполнение работ по подготовке техно-рабочего проекта на доукомплектование интеллектуальной транспортной системы регионального уровня объектами муниципального значения
# Pos [] Neg []
# 0 Выполнение работ по проектированию систем обеспечения информационной безопасности объектов информатизации для нужд филиала ФГУП ГЦСС
# Pos [] Neg []
# 0 Выполнение работ по производству аудиовизуальной продукции и трансляции в телеэфире информации общественно-значимой тематики о деятельности Законодательной Думы Томской области
# Pos [] Neg []
# 0 Выполнение работ по развитию подсистемы "Внутренний порталПФР" АИС ПФР-2
# Pos [{'портал': 1}] Neg [{'развитию подсистем': 1, 'работ по развит': 1}]
# 0 Выполнение работ по разработке интеграционных механизмов программного продукта "АВЕРС: Управление лесным фондом ПРОФ" для взаимодействия с формами-концентраторами Единого портала государственных услуг
# Pos [{'портал': 1}] Neg [{'аверс': 1}]
# 0 Выполнение работ по разработке комплекта документов регламентирующих процессы создания, развития, ввода в эксплуатацию и обследования информационных систем с проведением обследования и пусконаладочных работ государственных информационных систем Пермского края
# Pos [] Neg []
# 0 Выполнение работ по разработке модуля централизованного сбора сведений об обнаружении, предупреждении и ликвидации последствий компьютерных атак, а также реагированию на компьютерные инциденты центра кибербезопасности по реагированию на компьютерные инциденты платформы «ГосТех»
# Pos [] Neg []
# 0 Выполнение работ по разработке технического проекта модернизации объединенной сетевой инфраструктуры Социального фонда России
# Pos [] Neg []
# 0 Выполнение работ по созданию виртуального тура «Промышленность Поморья»
# Pos [] Neg []
# 0 Выполнение работ по созданию единой информационной сети всего парка оборудования и рабочих мест АО «ПЗЦМ»
# Pos [] Neg []
# 0 Выполнение работ по созданию и внедрению обучающего тренажера геофизических исследований в рамках «Югра НГК Проф» (горнодобывающая отрасль) федерального проекта «Профессионалитет»
# Pos [] Neg []
# 0 Выполнение работ по созданию комплекса программно-технических средств Координационного центра Оренбургской области
# Pos [] Neg []
# 0 Выполнение работ по созданию многофункционального узла безопасности
# Pos [] Neg []
# 0 Выполнение работ по созданию систем видеонаблюдения и контроля управления доступом для объектов филиалов АО "НОКК"
# Pos [] Neg []
# 0 Выполнение работ помонтажу,  инсталяции, настройке оборудования и программного обеспечения радиостудии
# Pos [] Neg []
# 0 Договор б/н
# Pos [] Neg []
# 0 Закупка на 2023 год на оказание услуг по учёту автомобильных дорог и искусственных дорожных сооружений с составлением технического паспорта и формированием базы дорожных данных.
# Pos [] Neg []
# 0 Закупка услуг сопровождения в Системе
# Pos [] Neg []
# 0 Комплект поддержки Информационно-технологического-сопровождения Медицина
# Pos [] Neg []
# 0 Комплект программного обеспечения для станков с ЧПУ
# Pos [] Neg []
# 0 Консультационные услуги в рамках Семинара-тренинга «CoGIS 10: От подготовки картографического проекта в настольной ГИС до настройки веб-карты»
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'консультаци': 1, 'консультационные услуг': 1}]
# 0 купли продажи
# Pos [] Neg []
# 0 Лицензия на использование модуля "Личный кабинет ЭДО" ПП Талисман SQL
# Pos [{'личный кабинет': 1}, {'личный кабинет': 1}] Neg [{'лицензи': 1}]
# 0 Лот № 17301-ЭКСП ДИТ-2024-ЯЭ «ОКПД2 62.02.30.000 Оказание услуг по предоставлению доступа и сопровождению базы данных "Техэксперт:Премиум"»
# Pos [{'базы данных': 1}] Neg [{'техэксперт': 1, 'услуг по предоставлен': 1}]
# 0 Мероприятия по автоматизации работы министерства строительства Самарской области
# Pos [] Neg []
# 0 Мониторинг и реагирование на компьютерные атаки и взаимодействие с НКЦКИ ФСБ России (ГосСопка)
# Pos [] Neg []
# 0 на выполнение работ по диспетчеризации и автоматизация котельной №9 с.Муслюмово
# Pos [{'автоматизация': 1}] Neg [{'диспетчеризац': 1}]
# 0 Настройка локальных сетей
# Pos [] Neg []
# 0 Неисключительное право использования электронной системы ЭС "Госфинансы". Простая неисключительная лицензия на использование Базы данных
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительное прав': 1, 'право использовани': 1}]
# 0 Неисключительные права на использование охраняемых законом результатов интеллектуальной деятельности для ЭВМ и базы данных (простая неисключительная лицензия) (далее право использования ЭС): Справочная Система "Охрана труда Плюс" Интернет-версия, срок действия лицензии 12 месяцев
# Pos [{'базы данных': 1}] Neg [{'лицензи': 2, 'неисключительные прав': 1, 'право использовани': 1}]
# 0 Неисключительные права на использование охраняемых законом результатов интеллектуальной деятельности для ЭВМ и базы данных (простая неисключительная лицензия) (далее право использования ЭС): Электронная Система "Госзаказ Плюс" Интернет-версия, срок действия лицензии 12 месяцев
# Pos [{'базы данных': 1}] Neg [{'лицензи': 2, 'неисключительные прав': 1, 'право использовани': 1}]
# 0 Обследование информационных систем и разработка организационно-распорядительной документации
# Pos [{'разработка': 1}] Neg []
# 0 Обслуживание учетных систем РКБ
# Pos [] Neg []
# 0 Оказание информационно-справочных услуг
# Pos [] Neg []
# 0 Оказание информационно-справочных услуг для КДО в ГБУЗ "ГКБ № 13 ДЗМ" в 2023-2025 гг.
# Pos [] Neg []
# 0 Оказание комплексных услуг по технической поддержке и адаптационному сопровождению Комплексной информационной системы «Государственные услуги в сфере образования в электронном виде» (КИС ГУСОЭВ) в части АИС «ЭЖ», АИС «ЭД», Сервиса «Веб.Учитель», Сервиса «МЭШ.Оценки», Сервиса «МЭШ.Чаты»
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'технической поддержк': 1}]
# 0 Оказание по установке и внедрению системы видеоконференцсвязи в Администрации города Норильска с передачей неисключительных (пользовательских) прав на использование программного обеспечения для видеоконференцсвязи для нужд Администрации города Норильска
# Pos [] Neg []
# 0 Оказание слуги по сопровождению прикладного программного обеспечения (программ для ЭВМ) Регионального сегмента единой государственной информационной системы в сфере здравоохранения Ростовской области (РС ЕГИСЗ) для нужд ГБУ РО "ЦГБ" в г. Новошахтинске
# Pos [] Neg []
# 0 Оказание услуг в области информационной безопасности
# Pos [] Neg []
# 0 Оказание услуг в области информационных технологий на судебных участках мировых судей Курской области
# Pos [] Neg []
# 0 Оказание услуг в области информационных технологий по расширению функциональных возможностей программного обеспечения автоматизированной билетно-пропускной системы TicketNet
# Pos [] Neg []
# 0 Оказание услуг на передачу неисключительных прав на использование базы данных Электронной Системы «Главный врач»
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1}]
# 0 Оказание услуг на поставку и внедрение автоматизированной интегрированной библиотечной системы "МегаПро" для филиала института в 2023 году
# Pos [] Neg []
# 0 Оказание услуг по актуализации и обновлению справочно-информационной базы данных захоронений
# Pos [{'базы данных': 1}] Neg [{'обновлен': 1, 'услуг по актуализ': 1}]
# 0 Оказание услуг по аппаратно-техническому обеспечению региональной системы автоматизации функций тарифного регулирования в Тверской области
# Pos [] Neg []
# 0 Оказание услуг по сопровождению автоматизированных информационных систем Единый центр услуг, Портал государственных и муниципальных услуг (функций) Краснодарского края, Реестр государственных услуг (функций) Краснодарского края
# Pos [{'портал': 1}] Neg [{'услуг по сопровожден': 1}]
# 0 Оказание услуг по техническому сопровождению подсистемы «Автоматизация процесса питания учащихся в общеобразовательных организациях Ханты-Мансийского автономного округа – Югры» и подсистемы «Электронный детский сад»
# Pos [{'автоматизация': 1}] Neg [{'техническому сопровождени': 1}]
# 0 Оказание услуг по сопровождению программ для ЭВМ системы учета платных услуг на базе программного продукта "1С:Розница ПРОФ" с использованием веб-версии "Модуль интеграции "1С:Розница ПРОФ" (ред.2.0) с медицинской информационной системой" для нужд ГБУЗ МО "МГКБ" в 2023 году
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'медицинской информационной систем': 1, 'услуг по сопровожден': 1, '1с': 2, 'сопровождению программ': 1, 'опровождению программ': 1}]
# 0 Оказание услуг по обследованию ИТ-инфраструктуры
# Pos [{'ит': 1}] Neg []
# 0 Услуга по разработке программного комплекса контроля стрессоустойчивости обучаемого на базе физиологических показателей и нейротехнологий
# Pos [] Neg []
# 0 Оказание услуг по сопровождению, технической поддержке и сервисному обслуживанию программы управления Интерактивным порталом Центр занятости населения Рязанской области
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1, 'услуг по сопровожден': 1, 'сервисному обслуживан': 1, 'обслуживанию программ': 1}]
# 0 Оказание услуг по мониторингу и администрированию СУБД
# Pos [] Neg []
# 0 Программное средство фильтрации негативного контента
# Pos [{'контент': 1}] Neg []
# 0 Оказание услуг по выполнению комплекса мероприятий по подготовке к аттестации и аттестации автоматизированной системы единой базовой интеграционной платформы на базе ПО ЕИП «Энербас» и подсистемы «Автоматизация процессов предоставления государственных услуг и осуществления государственных функций» ведомственной информационной системы поддержки деятельности центрального аппарата Министерства энергетики Российской Федерации на соответствие требованиям по защите информации
# Pos [{'автоматизация процессов': 1, 'автоматизация': 1}] Neg [{'защите информаци': 1}]
# 0 Оказание услуг по проектированию информационного взаимодействия (00009364-ЭА)
# Pos [] Neg []
# 0 Сопровождение справочно-правовой системы «Гарант»
# Pos [] Neg []
# 0 Оказание услуг по электронному документообороту с контрагентами, государственными и территориальными органами в течение 1096 календарных дней
# Pos [] Neg []
# 0 Оказание услуг по разработке сайта «Министерство сельского хозяйства и перерабатывающей промышленности Кузбасса»
# Pos [{'разработке сайта': 1}] Neg []
# 0 Оказание услуг по переносу базы данных из ПП "Эксперт" в 1С института и филиала института в 2023 году
# Pos [{'базы данных': 1}] Neg [{'1с': 1, 'услуг по перенос': 1}]
# 0 Оказание услуг по созданию программно-аппаратных комплексов для оснащения экспозиции Музея Обороны Тулы в рамках реализации национального проекта «Культура»
# Pos [] Neg []
# 0 Оказание услуг по популяризации продукции и услуг
# Pos [] Neg []
# 0 Продление: Простая неисключительная лицензия на использование Базы данных Справочная система «Госфинансы Плюс. Для всех сотрудников», срок действия лицензии 12 месяцев, Простая неисключительная лицензия на использование Базы данных Справочная система «Завуч: обучение и воспитание. Оптимальный» Плюс для всех сотрудников, срок действия лицензии 12 месяцев, Простая неисключительная лицензия на использование Базы данных Кадровая Справочная Система «Система Кадры», версия для бюджетных, казенных и автономных учреждений, срок действия лицензии 12 месяцев, однопользовательская, Простая неисключительная лицензия на использование Базы данных Электронная система «Госзаказ Плюс. Для всех сотрудников», срок действия лицензии 12 месяцев
# Pos [{'базы данных': 4}] Neg [{'бюджет': 1, 'лицензи': 8, 'продлени': 1}]
# 0 Фискализация безналичных платежей, включая аренду ККТ
# Pos [] Neg []
# 0 Сопровождение справочно-правовых систем через сеть Интернет
# Pos [] Neg []
# 0 Поставка аналитической платформы для автоматизированной системы персональных коммуникаций на основе использования больших данных
# Pos [] Neg []
# 0 Создание автоматизированной системы Интегрированная система пропуска через государственную границу Российской Федерации (в рамках ИКТ)
# Pos [] Neg []
# 0 Оказание услуг по интеграции программы для ЭВМ «Автоматизация контрольно-надзорной деятельности (Ревизор-СМАРТ)» и единой межведомственной системы документооборота Краснодарского края в Контрольно-счетной палате Краснодарского края
# Pos [{'автоматизация': 1}] Neg [{'услуг по интеграц': 1}]
# 0 Оказание услуг по предоставлению простой неисключительной лицензии на использование базы данных Электронная Система Госфинансы, Электронная Система Госзаказ
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'услуг по предоставлен': 1}]
# 0 Оказание услуг по программному сопровождению (технической поддержке) модуля «Интеграция» медицинской информационной системы «Медея» (Реестровый номер 2023.066690)
# Pos [{'интеграция': 1}, {'интеграция': 1}] Neg [{'технической поддержк': 1, 'медицинской информационной систем': 1}]
# 0 Оказание услуг по передаче неисключительных прав использования комплекта электронных базы данных (простая неисключительная лицензия) для нужд ФГБУЗ МСЧ №97 ФМБА России в 2024 году.
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительных прав': 1, 'прав использовани': 1, 'услуг по передач': 1}]
# 0 Сопровождение государственной информационной системы РТ "Бухгалтерский учет и отчетность государственных органов РТ и подведомственных им учреждений (ГИС РТ) на 4 квартал 2023г.
# Pos [] Neg []
# 0 Сопровождение ПО
# Pos [] Neg []
# 0 Создание Второй очереди информационной системы «Прикладная платформа «Государственные и муниципальные услуги»
# Pos [] Neg []
# 0 Приобретение сертификата расширенного мониторинга и настройки подсистемы защиты приложений от несанкционированного доступа и продления неисключительных прав на использование программного обеспечения подсистемы защиты приложений от несанкционированного доступа и подсистемы защиты вредоносного контента
# Pos [{'контент': 1}] Neg [{'неисключительных прав': 1, 'сертификат': 1, 'продлени': 1}]
# 0 Оказание услуг по модификации государственной информационной системы «Государственный заказ»
# Pos [] Neg []
# 0 Оказание услуг по сопровождению подсистемы Интернет-портал ЦИК России Государственной автоматизированной системы Российской Федерации "Выборы"
# Pos [{'портал': 1}] Neg [{'услуг по сопровожден': 1}]
# 0 Оказание услуг по методическому сопровождению развития и функционирования целевой модели дополнительного образования детей в Тульской области в рамках функционирования регионального модельного центра дополнительного образования детей
# Pos [] Neg []
# 0 Оказание услуг по переносу существующего программного обеспечения и базы данных, используемых в МБУ «ЦБ КОиН» для ведения бухгалтерского учета «Парус-Бюджет 8» на новый сервер с предустановленной операционной системой Linux
# Pos [{'базы данных': 1}] Neg [{'бюджет': 1, 'парус': 1, 'услуг по перенос': 1}]
# 0 Сопровождение ПО для нужд ГБУЗ СО "Большеглушицкая ЦРБ"
# Pos [] Neg []
# 0 Сопровождение прикладного программного обеспечения (программ для ЭВМ) РС ЕГИСЗ для ГБУ РО "ГБ № 2" в г. Шахты
# Pos [] Neg []
# 0 Оказание услуг по информированию населения об основных событиях социально-экономического развития, общественно-политической жизни, освещению деятельности органов местного самоуправления городского округа Красногорск и Московской области путем изготовления и размещения информационных материалов в печатных СМИ в 4-м квартале 2023 года
# Pos [] Neg []
# 0 Оказание услуг по обеспечению безопасности информации, обрабатываемой в информационной системе «Единый информационный портал Новгородской области» государственного учреждения «Новгородский информационно-аналитический центр»
# Pos [{'портал': 1}] Neg [{'услуг по обеспечен': 1}]
# 0 Оказание услуг по сопровождению электронной базы данных программы NormaCS
# Pos [{'базы данных': 1}] Neg [{'услуг по сопровожден': 1}]
# 0 Оказание услуг по диагностике программно-аппаратного комплекса зав. № GP0002753 инв. № 1012441172, с выездом специалиста
# Pos [] Neg []
# 0 Приобретение неисключительных прав (лицензии) на программный продукт контент-фильтрации
# Pos [{'контент': 1}] Neg [{'лицензи': 1, 'неисключительных прав': 1}]
# 0 Передача прав на использование программного обеспечения для нужд Уфимского университета
# Pos [] Neg []
# 0 Оказание услуг по сопровождению программного обеспечения АИС «ИМЦ: Комплексная автоматизация бюджетного учреждения» для Государственного бюджетного учреждения здравоохранения Самарской области «Самарская городская станция скорой медицинской помощи»
# Pos [{'автоматизация': 1}] Neg [{'бюджет': 2, 'услуг по сопровожден': 1, 'сопровождению программ': 1, 'опровождению программ': 1}]
# 0 Оказание услуг по клиентскому сопровождению работы комплекса программ (КП) "Система доходов и расходов по содержанию и эксплуатации домовладения" и информационной системы (ИС) "Жилищный фонд" на 2024 год
# Pos [] Neg []
# 0 ОКПД2 62.09.20.190 Создание/внедрение и интеграция Единой системы управления нормативно-справочной информацией ПАО «РусГидро» и Единой учетной системы на базе 1С:Предприятие 8.3 для нужд филиала "Колымская ГЭС имени Фриштера Ю.И." ПАО "Колымаэнерго", лот №0002-ЭКСП ДИТ-2024-КЭ-КГЭС
# Pos [{'интеграция': 1}, {'интеграция': 1}] Neg [{'1с': 1}]
# 0 Передача права использования технической поддержки информационной системы "Информационный интернет-портал Правительства Хабаровского края "Открытый Регион"
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1, 'права использовани': 1}]
# 0 Оказание услуги по подключению и сопровождению сегмента Единой системы электронного документооборота и делопроизводства исполнительных органов государственной власти Санкт-Петербурга для нужд Заказчика
# Pos [] Neg []
# 0 Услуги по предоставлению ключей активации сервиса прямой технической поддержки и сертификатов технической поддержки на средства защиты информации для нужд государственного автономного учреждения «Технопарк в сфере высоких технологий «ИТ-парк».
# Pos [{'ит': 1}] Neg [{'технической поддержк': 2, 'защиты информаци': 1, 'сертификат': 1, 'услуги по предоставлен': 1}]
# 0 Оказание услуг по продлению неисключительных прав на использование межсетевого экрана уровня веб-приложений Positive Technogies Application Firewall
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'неисключительных прав': 1, 'продлени': 1}]
# 0 Оказание услуг по поддержанию постоянной эксплуатационной готовности кабелей связи для нужд Сыктывкарского и Воркутинского Центров ОВД филиала «Аэронавигация Северо-Запада» ФГУП «Госкорпорация по ОрВД»
# Pos [] Neg []
# 0 Предоставление доступа и сопровождение базы данных (информационного продукта вычислительной техники), содержащей информацию о текущем состоянии законодательства Российской Федерации, путем предоставления в электронном виде по каналам связи посредством телекоммуникационной сети Интернет формируемых Исполнителем текущих версий базы данных
# Pos [{'базы данных': 2}] Neg []
# 0 Оказание услуг по организации производства и трансляции в радиоэфире на территории Томской области аудиоматериалов о деятельности Законодательной Думы Томской области
# Pos [] Neg []
# 0 Оказание услуг по передаче права использования электронной базы данных на условиях простой (неисключительной) лицензии для нужд ГБУ РС (Я) "Нерюнгринская ЦРБ"
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'права использовани': 1, 'услуг по передач': 1}]
# 0 Реконструкция и строительство аэропорта Грозный «Северный» в части выполнения монтажных и пуско-наладочных работ оборудования АТИС с системой СВИП
# Pos [] Neg []
# 0 Оказание услуг по сопровождению и эксплуатации Информационной системы Единый портал избирательных комиссий Пермского края
# Pos [{'портал': 1}] Neg [{'услуг по сопровожден': 1}]
# 0 Программное обеспечение для информационного терминала модели ИМДУ-43
# Pos [] Neg []
# 0 Работы по адаптации и созданию дополнительного функционала СИСТЕМ
# Pos [] Neg []
# 0 Передача прав на использование программного обеспечения
# Pos [] Neg []
# 0 Поставка и ввод в эксплуатацию программного обеспечения, реализующего функции криптографического клиента
# Pos [] Neg []
# 0 Оказание услуг по технической экспертизе компьютерной и организационной техники
# Pos [] Neg []
# 0 Оказание услуг по сопровождению и модернизации автоматизированной системы решения нестандартных задач, разработке портала цифровых технологий
# Pos [{'портал': 1}] Neg [{'услуг по сопровожден': 1}]
# 0 Оказание услуг по информированию собственников помещений в многоквартирных домах на территории Новосибирской области о задолженности по оплате взносов на капитальный ремонт.
# Pos [] Neg []
# 0 Оказание услуг по мониторингу и предоставлению аналитической отчетности выполнения Перевозчиками транспортной работы на маршрутах, выполняемых по заказу Комитета Ленинградской области по транспорту.
# Pos [] Neg []
# 0 Оказание услуг по переводу регионального сегмента государственной информационной системы Брянской области "Система обеспечения вызова экстренных оперативных служб по единому номеру "112" на базе единых дежурно-диспетчерских служб муниципальных образований Брянской области" на использование отечественного офисного программного обеспечения (3 этап)
# Pos [] Neg []
# 0 Оказание услуг по информационно-техническому ИС на 2024 год
# Pos [] Neg []
# 0 Оказание услуг по организации и проведению онлайн-видеотрансляции мероприятий для нужд ФГУП «ВНИИМ им.Д.И.Менделеева»
# Pos [] Neg []
# 0 Оказание услуг по разработке скриптов для АРМ по проведению поверки средств измерений
# Pos [] Neg []
# 0 Оказание услуг по осуществлению многоуровневой защиты веб-приложений Заказчика
# Pos [{'веб': 1}, {'веб': 1}] Neg []
# 0 Оказание услуг по техническому обслуживанию и поддержке мультимедийного оборудования
# Pos [{'мультимеди': 1}] Neg [{'техническому обслуживани': 1}]
# 0 Оказание услуг по техническому сопровождению информационной системы (портала) Ставропольского края «Учимся вместе» в целях обеспечения в Ставропольском крае доступа инвалидов, лиц с ограниченными возможностями здоровья и граждан, имеющих детей с ограниченными возможностями здоровья, к информации о доступности образования для обеспечения нужд Ставропольского края
# Pos [{'портал': 1}] Neg [{'техническому сопровождени': 1}]
# 0 Оказание услуг по техническому сопровождению системы "Учёт начислений и платежей", являющейся подсистемой "Регионального портала государственных услуг Ставропольского края" для обеспечения нужд Ставропольского края
# Pos [{'портал': 1}] Neg [{'техническому сопровождени': 1}]
# 0 Оказание услуг по передаче простой неисключительной лицензии на использование базы данных  электронный системы "Главная медсестра"
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'услуг по передач': 1}]
# 0 Приобретение сертификатов на услуги технической поддержки продуктов и программного обеспечения системы информационной безопасности ИТ-инфраструктуры
# Pos [{'ит': 1}] Neg [{'технической поддержк': 1, 'сертификат': 1}]
# 0 Оказание услуг по технической поддержке (модернизации) веб-сайта в сети Интернет
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'технической поддержк': 1}]
# 0 Оказание услуг по созданию и внедрению ПАК «ИТ – инфраструктура»
# Pos [{'ит': 1}] Neg []
# 0 Оказание услуг по технической поддержке и настройке Корпоративного портала 1С-Битрикс24 Заказчика
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1, '1с': 1}]
# 0 Оказание услуги по разработке и созданию официального сайта ГБУ «Владимирская областная СББЖ»
# Pos [] Neg []
# 0 Оказание услуг по оценке технического состояния оборудования в сфере информационно-коммуникационных технологий для обеспечения государственных нужд Управления Федерального казначейства по Забайкальскому краю
# Pos [] Neg []
# 0 Оказание услуг по системному сопровождению единой ведомственной мультисервисной сети и системы виртуализации и мониторинга информационно-вычислительной системы Росстата (ИВС Росстата)
# Pos [] Neg []
# 0 Развитие государственной информационной системы Самарской области «Региональный информационный реестр документов и результатов комплексных инженерных изысканий на территории Самарской области»
# Pos [] Neg []
# 0 Приобретение электронного ключа к программному комплексу "ЭРА-воздух"
# Pos [] Neg []
# 0 Оказание услуг по комплексному обслуживанию и администрированию базовых вычислительных комплексов информационно-вычислительной сети, обеспечивающей функционирование государственных информационных систем Санкт - Петербурга в октябре-декабре 2023 года и январе 2024 года, для государственных нужд Санкт- Петербурга
# Pos [] Neg []
# 0 сопровождения программного обеспечения базы данных на компьютерах
# Pos [{'базы данных': 1}] Neg [{'сопровождения программ': 1, 'опровождения программ': 1}]
# 0 Поставка интерактивных учебных комплексов для нужд ГБПОУ МГОК.
# Pos [] Neg []
# 0 Продление  неисключительных прав использования Базы данных справочной системы  «Главная медсестра»
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1, 'прав использовани': 1, 'продлени': 1}]
# 0 Передача неисключительных прав использования базы данных "Образование", предназначенной для обеспечения учебных и воспитательных целей и повышения эффективности воспитательно-образовательного процесса в соответствии с ФГОС
# Pos [{'базы данных': 1}] Neg [{'образование': 1, 'неисключительных прав': 1, 'прав использовани': 1}]
# 0 Поставка в 2023 году программного обеспечения экранного доступа для инвалидов, в том числе детей-инвалидов, с нарушениями функций одновременно слуха и зрения
# Pos [] Neg []
# 0 Яндекс 360 для бизнеса (тариф базовый) на 150 пользователей на год
# Pos [] Neg []
# 0 Оказание услуг, направленных на выполнение функций учреждения (предоставление лицензии на право использования программного обеспечения для разработки цифрового образовательного контента в рамках реализации ФП «Профессионалитет»)
# Pos [{'контент': 1}] Neg [{'лицензи': 1, 'право использовани': 1}]
# 0 Поставка неисключительных (пользовательских) прав на использование программного обеспечения Dr.Web Desktop Security Suite  или эквивалент
# Pos [] Neg []
# 0 Оказание услуг по проведению телеконференций для нужд администрации Краснодарского края
# Pos [] Neg []
# 0 Поставка и монтаж оборудования для организации электронной очереди
# Pos [] Neg []
# 0 Оказание услуг по предоставлению неисключительных прав использования (простая неисключительная лицензия) базы данных электронной справочной системы "Система Госфинансы"
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительных прав': 1, 'прав использовани': 1, 'услуг по предоставлен': 1}]
# 0 Предоставления права пользования информационной системой персональных данных "Ивроссы:ИнформСоцПроект" автоматизированной и автоматической обработки данных
# Pos [] Neg []
# 0 Оказание услуг по предоставлению прав доступа к порталу "Информационно-технологическое сопровождение программы "1С:Предприятия" для нужд муниципального казенного учреждения «Управление материально-технического обеспечения деятельности органов местного самоуправления города Нижневартовска»
# Pos [{'портал': 1}] Neg [{'1с': 1, 'сопровождение программ': 1, 'опровождение программ': 1, 'услуг по предоставлен': 1}]
# 0 Услуги по предоставлению неисключительного права (лицензии) на использование сотрудниками учреждения модуля «Личный кабинет ЭДО» программного продукта «Комплексная система автоматизации управления бюджетными учреждениями «Талисман SQL»
# Pos [{'личный кабинет': 1}, {'личный кабинет': 1}] Neg [{'бюджет': 1, 'лицензи': 1, 'неисключительного прав': 1, 'услуги по предоставлен': 1}]
# 0 Услуга по предоставлению неисключительного права (лицензии) на использование сотрудниками учреждения модуля «Личный кабинет ЭДО» программного продукта «Комплексная система автоматизации управления бюджетными учреждениями «Талисман SQL».
# Pos [{'личный кабинет': 1}, {'личный кабинет': 1}] Neg [{'бюджет': 1, 'лицензи': 1, 'неисключительного прав': 1, 'услуга по предоставлен': 1}]
# 0 Сопровождение ЭПС «Система Гарант» для нужд КФ ФГБОУВО «РГУП» г. Казань
# Pos [] Neg []
# 0 Оказание услуг по обследованию информационных систем персональных данных, разработке моделей угроз персональных данных, разработке технического задания на создание системы защиты персональных данных
# Pos [] Neg []
# 0 Определение подрядчика на выполнение работ по созданию подсистемы обмена федеративными сообщениями и документами между ПАО «Россети» и дочерними обществами Группы компаний «Россети» в автоматизированной системе управленческого документооборота ПАО «Россети Московский регион».
# Pos [] Neg []
# 0 Проведение обследования (аудита) процессов обработки и защиты персональных данных в учреждении
# Pos [] Neg []
# 0 Оказание услуг по созданию и установке мультимедийной системы
# Pos [{'мультимеди': 1}] Neg []
# 0 Оказание услуг по предоставлению прав доступа к порталу "Информационно-технологическое сопровождение программы "1С:Предприятия" для нужд администрации города Нижневартовска»
# Pos [{'портал': 1}] Neg [{'1с': 1, 'сопровождение программ': 1, 'опровождение программ': 1, 'услуг по предоставлен': 1}]
# 0 Услуги по внедрению и модернизации базы данных на основе ПП "Парус"
# Pos [{'базы данных': 1}] Neg [{'парус': 1, 'услуги по внедрен': 1}]
# 0 Услуги по продлению неисключительных прав использования Базы данных электронной системы "Госфинансы"
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1, 'прав использовани': 1, 'продлени': 1}]
# 0 Оказание услуг предоставления права пользования информационной системой персональных данных «Ивроссы: Информ СоцПроект» автоматизированной и автоматической обработки данных
# Pos [] Neg []
# 0 Осуществление работ (услуг) по доработке неисключительных прав (лицензий) дополнительного модуля «Интеграция с ЕЛК» для действующего в Челябинской области модуля «Е-Услуги. Образование» государственной информационной системы «Образование в Челябинской области» для обеспечения подключения к виду сведений системы межведомственного электронного взаимодействия «Передача статусов и предоставление результатов государственных и муниципальных услуг».
# Pos [{'интеграция': 1}, {'интеграция': 1}] Neg [{'доработк': 1, 'образование': 2, 'лицензи': 1, 'неисключительных прав': 1}]
# 0 Услуга по созданию интеллектуальной транспортной системы Владимирской городской агломерации в объеме 1 уровня зрелости
# Pos [] Neg []
# 0 Оказание услуг по технической поддержке и обслуживанию автоматизированной системы "Адресная социальная помощь" с интегрируемым комплексом «Интеграция с системой межведомственного электронного взаимодействия»
# Pos [{'интеграция': 1}, {'интеграция': 1}] Neg [{'технической поддержк': 1}]
# 0 Оказание услуг по приобретению неисключительных прав на доступ к программному обеспечению «Здравпортал: Платные услуги» и сопровождению для нужд Государственного бюджетного учреждения здравоохранения Самарской области «Тольяттинская городская клиническая поликлиника №3»
# Pos [{'портал': 1}] Neg [{'бюджет': 1, 'неисключительных прав': 1}]
# 0 Оказание услуг по разработке программно-методического обеспечения профессиональных модулей образовательных программ профессионалитета по профессиям и специальностям по отрасли "Правоохранительная сфера и управление"
# Pos [] Neg []
# 0 Продление неисключительного права использования электронной Базы данных (простая неисключительная лицензия) для нужд СПб ГБУЗ «Городская больница № 9».
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительного прав': 1, 'права использовани': 1, 'продлени': 1}]
# 0 Оказание услуг по по модернизации региональной информационной системы «Электронный колледж» способом установки и адаптации программы для ЭВМ и передачи права на ее использование
# Pos [] Neg []
# 0 Оказание услуг по технической защите и аттестации информационной системы обеспечения мониторинга безопасности СПб ГБУЗ «Детский санаторий «Звездочка»
# Pos [] Neg []
# 0 Оказание услуг по предоставлению неисключительных (пользовательских) прав использования Базы данных Электронная система «Госфинансы»
# Pos [{'базы данных': 1}] Neg [{'прав использовани': 1, 'услуг по предоставлен': 1}]
# 0 Сопровождение системы Консультант-Плюс
# Pos [] Neg []
# 0 Поставка и внедрение в промышленную эксплуатацию в инфраструктуру Заказчика Программно-аппаратного комплекса для защиты сети (Next Generation Firewall)
# Pos [] Neg []
# 0 Оказание услуг по сопровождению базы данных справочной правовой системы «КонсультантПлюс»
# Pos [{'базы данных': 1}] Neg [{'консультантплюс': 1, 'услуг по сопровожден': 1}]
# 0 Оказание услуг по созданию муниципальной геоинформационной системы муниципального образования «город Усть-Илимск» Иркутской области и актуализации технической документации, отображающей текущее состояние и будущее развитие систем центрального теплоснабжения, центрального водоснабжения и центрального водоотведения.
# Pos [] Neg []
# 0 Оказание услуг по внедрению прикладной программы «1С: Зарплата и кадры государственного учреждения 8 ПРОФ» и переносу базы данных из программы «ИнТеП – Заработная плата»
# Pos [{'базы данных': 1}] Neg [{'1с': 1, 'услуг по внедрен': 1}]
# 0 Оказание услуг по сопровождению программного обеспечения и предоставлению неисключительного права использования электронной Базы данных электронных систем "Госфинансы" и "Госзаказ"
# Pos [{'базы данных': 1}] Neg [{'неисключительного прав': 1, 'права использовани': 1, 'услуг по сопровожден': 1, 'сопровождению программ': 1, 'опровождению программ': 1}]
# 0 Оказание услуг по технической поддержке комплекса региональных информационных систем: - «Система межведомственного электронного взаимодействия Курской области»; - «Портал государственных и муниципальных услуг Курской области»; - «Система исполнения услуг Курской области»
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1}]
# 0 Услуги по передачи неисключительных прав использования Базы данных Справочная Система «Госфинансы Плюс»
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1, 'прав использовани': 1, 'услуги по передач': 1}]
# 0 Оказание услуг по продлению неисключительных прав на использование базы данных электронных систем «Госфинансы» и «Госзаказ»
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1, 'продлени': 1}]
# 0 Оказание услуг по миграции на актуальную версию программы для ЭВМ "Directum RX для нужд ООО "Газпром трансгаз Екатеринбург" в 2023 году 00075268
# Pos [] Neg []
# 0 Работы по обследованию территории объекта Заказчика с целью выбора мест размещения системы защиты от беспилотных летательных аппаратов
# Pos [] Neg []
# 0 Оказание услуг по оценке эффективности реализованных в рамках системы защиты персональных данных мер по обеспечению безопасности персональных данных
# Pos [] Neg []
# 0 Услуги по передачи неисключительных прав использования Базы данных Справочная Система «Госфинансы Плюс», электронной системы «Система Кадры» для бюджетных учреждений
# Pos [{'базы данных': 1}] Neg [{'бюджет': 1, 'неисключительных прав': 1, 'прав использовани': 1, 'услуги по передач': 1}]
# 0 Передача неисключительных прав использования электронной Базы данных (простая неисключительная лицензия)
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительных прав': 1, 'прав использовани': 1}]
# 0 Услуга по созданию информационной системы управления кадровым составом для нужд Администрации городского округа "город Дербент"
# Pos [] Neg []
# 0 Оказание услуг по созданию подсистемы информационной безопасности региональной автоматизированной системы централизованного оповещения населения Чукотского автономного округа
# Pos [] Neg []
# 0 Оказание услуг по переносу существующего программного обеспечения и базы данных, используемых в МБУ «ЦБ КОиН» для ведения бухгалтерского учета «Парус-Бюджет 8» на новый сервер с предустановленной операционной системой Linux
# Pos [{'базы данных': 1}] Neg [{'бюджет': 1, 'парус': 1, 'услуг по перенос': 1}]
# 0 Оказание услуг по разработке АРМ «Оператор» программы для ЭВМ Программный комплекс «Информационная система управления финансами» (ПК «ИСУФ»)
# Pos [] Neg []
# 0 Оказание услуг по проведению защищенного виртуального центра обработки данных и организации доступа для нужд ГБУ РО "ОКЦФП"
# Pos [] Neg []
# 0 Оказание услуг по передаче неисключительных (лицензионных) прав на опцию «Интеграция с постаматом» и услуг по адаптации опции для автоматизированной информационной системы для многофункциональных центров предоставления государственных и муниципальных услуг Рязанской области
# Pos [{'интеграция': 1}, {'интеграция': 1}] Neg [{'лицензи': 1, 'услуг по передач': 1, 'услуг по адапт': 1}]
# 0 Оказание услуг по созданию электронного учебного материала для курса "Группа компаний "Софкомфлот" в системе электронного обучения для нужд МГУ им. адм. Г.И. Невельского
# Pos [] Neg []
# 0 Услуги по технической поддержке ИТ-инфраструктуры и сервиса печати
# Pos [{'ит': 1}] Neg [{'технической поддержк': 1}]
# 0 Оказание услуг по обновлению и технической поддержке корпоративного портала Центра
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1, 'обновлен': 1}]
# 0 Оказание услуг по предоставлению продления неисключительного права (простая неисключительная лицензия на использование Базы данных Электронная система «Главный врач»).
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительного прав': 1, 'продлени': 1, 'услуг по предоставлен': 1}]
# 0 Оказание услуг по передаче права использования электронной базы данных на условиях простой  (неисключительной) лицензии
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'права использовани': 1, 'услуг по передач': 1}]
# 0 Сопровождение Электронного периодического справочника "Система ГАРАНТ"
# Pos [] Neg []
# 0 Оказание услуг по созданию информационной системы «Автоматическая телефонная станция службы единой горячей линии Забайкальского края» (00007886-ЭА)
# Pos [] Neg []
# 0 Оказание услуг по продлению неисключительных прав использования электронной базы данных "Завуч: обучение и воспитание" и "ЭС Образование"(простая неисключительная лицензия).
# Pos [{'базы данных': 1}] Neg [{'образование': 1, 'лицензи': 1, 'неисключительных прав': 1, 'прав использовани': 1, 'продлени': 1}]
# 0 Электронный аукцион на выполнение работ по созданию и настройке функционала системы электронного документооборота ГБУЗ «ДЦЛИ ДЗМ»
# Pos [] Neg []
# 0 Поставка и ввод в эксплуатацию программно-аппаратных комплексов и передачу неисключительных (пользовательских) прав программного обеспечения
# Pos [] Neg []
# 0 Поставка универсальных шлюзов безопасности, выполняющих  функции сервера защищенной сети передачи данных
# Pos [] Neg []
# 0 Услуги по предоставлению простых (неисключительных) прав использования электронной базы данных Электронная система "Госфинансы"
# Pos [{'базы данных': 1}] Neg [{'прав использовани': 1, 'услуги по предоставлен': 1}]
# 0 Оказание услуг по установке, разработке, адаптации, модификации, тестированию и сопровождению программ для ЭВМ системы "1С:Предприятие" и баз данных, включая базы данных "1С:ИТС", а также связанных с сопровождением консультационных услуг
# Pos [{'базы данных': 1}] Neg [{'консультаци': 1, 'консультационных услуг': 1, '1с': 2, 'сопровождению программ': 1, 'опровождению программ': 1, 'услуг по установк': 1}]
# 0 Оказание услуг по передаче неисключительных (лицензионных) прав на опцию «Портал МФЦ» и услуг по адаптации опции для автоматизированной информационной системы для многофункциональных центров предоставления государственных и муниципальных услуг Рязанской области
# Pos [{'портал': 1}] Neg [{'лицензи': 1, 'услуг по передач': 1, 'услуг по адапт': 1}]
# 0 Оказание услуг по продлению неисключительного права использования Базы данных (простая неисключительная лицензия) электронная система "Госфинансы"
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительного прав': 1, 'права использовани': 1, 'продлени': 1}]
# 0 Разработка и создание автоматизированной системы учета электроэнергии (АСКУЭ)
# Pos [{'разработка': 1}] Neg []
# 0 Услуги по созданию автоматизированной информационной системы подачи заявлений МУП «Водоканал» в Государственный Комитет Республики Татарстан по тарифам»
# Pos [] Neg []
# 0 Оказание услуг по продлению неисключительных прав на использование базы данных электронных систем «Госфинансы» и «Госзаказ»" 244.226
# Pos [{'базы данных': 1}] Neg [{'неисключительных прав': 1, 'продлени': 1}]
# 0 Передача прав  на условиях простой (неисключительной) лицензии,  обновлений версий программы для ЭВМ «ГРАНД-Смета» и базы данных «ФСНБ-2022»
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'гранд-смета': 1, 'обновлен': 1}]
# 0 Оказание услуг по продлению неисключительного права использования электронной базы данных (простая неисключительная лицензия) справочной системы «Система Госфинансы (ПЛЮС)»
# Pos [{'базы данных': 1}] Neg [{'лицензи': 1, 'неисключительного прав': 1, 'права использовани': 1, 'продлени': 1}]
# 0 Право заключения договора оказания услуг по техническому обслуживанию Комплексной системы управления уязвимостями (КСУУ), Подсистемы защиты веб-ресурсов (ПЗВП), Функционального модуля оперативного контроля межсетевого взаимодействия (ФМОКМВ), Подсистемы комплексного анализа уязвимости приложений (ПКАУП), Системы контроля доступа привилегированных пользователей (СКДПП), Единой системы антивирусной защиты (ЕСАЗ), Системы оперативного контроля информационной безопасности (СОКИБ), Подсистемы обнаружения вторжений (ПОВ), Подсистемы аутентификации, авторизации и контроля доступа (ПААКД), Подсистемы межсетевого экранирования нового поколения (ПМЭ НП), и предоставления подписки (доступа) к программному обеспечению VDS-серверов и AnyRun (3395111)
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'антивирус': 1, 'техническому обслуживани': 1, 'право заключен': 1}]
# 0 Оказание услуг по разработке целевой ИТ-архитектуры корпоративной информационной системы АО «ОЭК» для перехода на отечественное ПО
# Pos [{'ит': 1}] Neg []
# 0 оказание услуг по установке  (обновлению), тестированию, сопровождению программ для ЭВМ системы «1С:Предприятие» , включая базы данных 1С:ИТС, а также связанные с сопровождением консультационные услуги для нужд Арзамасского филиала ФГУП «ВНИИ «Центр»
# Pos [{'базы данных': 1}] Neg [{'консультаци': 1, 'консультационные услуг': 1, '1с': 2, 'обновлен': 1, 'сопровождению программ': 1, 'опровождению программ': 1, 'услуг по установк': 1}]
# 0 Оказание услуг по сопровождению программы для ЭВМ «1С-Битрикс24. Лицензия Энтерпрайз» (Корпоративный портал) ФГБУ «Рослесинфорг»
# Pos [{'портал': 1}] Neg [{'лицензи': 1, 'услуг по сопровожден': 1, '1с': 1, 'сопровождению программ': 1, 'опровождению программ': 1}]
# 0 Оказание услуг по созданию и развитию единой информационной системы, содержащей сведения о проведении реабилитационных и абилитационных мероприятий инвалидам, в том числе детям-инвалидам
# Pos [] Neg []
# 0 Предоставление права на использование новых версий методических компонентов программы для ЭВМ "Олимпокс: Предприятие", "Олимпокс: Редактор"
# Pos [] Neg []
# 1 № 23-ЭА-108 Работы по адаптации автоматизированной информационной системы ОБУ «УМФЦ Липецкой области» для предоставления услуг Социального фонда Российской Федерации
# Pos [] Neg []
# 1 № 23-ЭА-83 Работы по адаптации автоматизированной информационной системы многофункциональных центров предоставления государственных и муниципальных услуг Липецкой области для ОБУ «УМФЦ Липецкой области»
# Pos [] Neg []
# 1 № 48-ЭА-23: услуги по усовершенствованию региональной информационной системы «Электронная школа»
# Pos [] Neg []
# 1 № зз-27112-2023 Модернизация лабораторно-информационной системы
# Pos [] Neg []
# 1 Внедрение ведомственной информационной системы регионального государственного строительного надзора
# Pos [] Neg []
# 1 Выполнение комплекса работ по переводу и обеспечению функционирования региональной информационной системы в сфере закупок товаров, работ, услуг для обеспечения нужд Рязанской области "WEB-Торги-КС" на отечественное ПО
# Pos [] Neg []
# 1 Выполнение работ по второму этапу создания государственной информационной системы «Учет государственных жилищных программ»
# Pos [] Neg []
# 1 Выполнение работ по доработке государственной информационной системы Приморского края «Региональный портал государственных и муниципальных услуг Приморского края» в части разработки опроса для граждан в рамках стандарта «Государство для людей»
# Pos [{'портал': 1}] Neg [{'доработк': 1}]
# 1 Выполнение работ по интеграции подсистемы «Автоматизация процессов предоставления государственных услуг и осуществления государственных функций» Ведомственной информационной системы поддержки деятельности центрального аппарата (ВИС) Минэнерго России с подсистемой «Единый реестр учета лицензий (разрешений)» федеральной государственной информационной системы «Федеральный реестр государственных и муниципальных услуг (функций)» и автоматизации направления статусов и результатов предоставления государственных услуг в личный кабинет заявителя в федеральной государственной информационной системе «Единый портал государственных и муниципальных услуг (функций)»
# Pos [{'портал': 1, 'личный кабинет': 1}, {'личный кабинет': 1}, {'автоматизация процессов': 1, 'автоматизация': 1}] Neg [{'лицензи': 1}]
# 1 Выполнение работ по комплексному обслуживанию государственной информационной системы «Закупки Вологодской области»
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развитию Государственной информационной системы «Управление выполнением формальных проверок возможности совершения юридически значимых действий»
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки подсистемы интеграции с государственной информационной системой обеспечения градостроительной деятельности Российской Федерации
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки подсистемы интеграции с Инвестиционной картой Республики Башкортостан
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки подсистемы подготовки разрешений на ввод в эксплуатацию объекта культурного наследия (памятника истории и культуры) народов Российской Федерации федерального значения, объектов культурного наследия регионального значения и разрешений на строительство в случае, если при проведении работ по сохранению объекта культурного наследия затрагиваются конструктивные и другие характеристики надежности и безопасности такого объекта
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки подсистемы цифровизации муниципальной услуги «Предоставление сведений, документов и материалов, содержащихся в государственной информационной системе обеспечения градостроительной деятельности Республики Башкортостан»
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки подсистемы цифровизации муниципальной услуги «Присвоение и аннулирование адресов»
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развития государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки программного обеспечения подсистемы цифровизации процесса согласования документации по планировке территории (2 этап)
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования региональной информационной системы   обязательного медицинского страхования Республики Башкортостан для нужд государственного учреждения Территориальный фонд обязательного медицинского страхования Республики Башкортостан
# Pos [] Neg []
# ...
# Pos [{'созданию сайта': 1}] Neg []
# 1 Выполнение работ по сопровождению и развитию государственной информационной системы «Электронный социальный регистр населения Ямало-Ненецкого автономного округа»
# Pos [] Neg []
# 1 Закупка услуги комплексного сервиса обеспечения функционирования регионального сегмента единой государственной информационной системы в сфере здравоохранения в Ростовской области (РС ЕГИСЗ)
# Pos [] Neg []
# 1 Комплексное обслуживание информационной системы
# Pos [] Neg []
# 1 модернизацию автоматизированной информационной системы «Охотуправление» с целью обеспечения предоставления региональных массовых социально значимых услуг в электронном виде с применением цифровых регламентов
# Pos [] Neg []
# 1 Модернизация государственной информационной системы «Социальный регистр населения Республики Татарстан»
# Pos [] Neg []
# 1 Модернизация и расширение сегмента Федеральной государственной информационной системы "Единая информационная база по реализации мероприятий, связанных с обеспечением безопасности донорской крови и её компонентов, развитием организацией и пропагандой донорства крови и её компонентов" в Новосибирской области, включая поставку, ввод в эксплуатацию и передачу оборудования и программного обеспечения
# Pos [] Neg []
# 1 Модернизация и расширение сегмента Федеральной государственной информационной системы «Единая информационная база по реализации мероприятий, связанных с обеспечением безопасности донорской крови и ее компонентов, развитием, организацией и пропагандой донорства крови и ее компонентов» в Новосибирской области, включая поставку, ввод в эксплуатацию и передачу оборудования и программного обеспечения
# Pos [] Neg []
# 1 Модернизация и расширение сегмента Федеральной государственной информационной системы «Единая информационная база по реализации мероприятий, связанных с обеспечением безопасности донорской крови и ее компонентов, развитием, организацией и пропагандой донорства крови и ее компонентов» в Новосибирской области, включая поставку, ввод в эксплуатацию и передачу оборудования и программного обеспечения
# Pos [] Neg []
# 1 на оказание услуг по созданию информационного портала "1000 маршрутов" для нужд ФГБОУ ДО ФЦДО
# Pos [{'портал': 1}] Neg []
# 1 на оказание Услуг по созданию сервиса передачи данных в "Федеральный регистр граждан, имеющих право на обеспечение лекарственными препаратами, медицинскими изделиями и специализированными продуктами лечебного питания за счет бюджетных ассигнований федерального бюджета и бюджетов субъектов Российской федерации" (ФР ЛЛО), из прикладного программного обеспечения подсистемы "Региональная медицинская информационная система" государственной информационной системы в сфере здравоохранения Челябинской области в части сервиса веб-подсистемы "Выписка льготных рецептов и учет ОНЛС" лекарственного обеспечения граждан льготных категорий лекарственными препаратами, медицинскими изделиями и специализированными продуктами лечебного питания в учреждениях здравоохранения Челябинской области
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'бюджет': 3, 'медицинская информационная систем': 1}]
# 1 Оказание комплексных услуг по технической поддержке и адаптационному сопровождению Комплексной информационной системы «Государственные услуги в сфере образования в электронном виде» в части Сервиса «Веб.Олимпиады.Организатор», Сервиса «Веб.Олимпиады.Учащийся», Сервиса «МЭШ.Олимпиады»
# Pos [{'веб': 2}, {'веб': 2}] Neg [{'технической поддержк': 1}]
# 1 Оказание услуг  по сопровождению компонента «Информационная система «Портал пациента»» центрального узла регионального сегмента единой государственной информационной системы в сфере здравоохранения Ханты-Мансийского автономного округа – Югры
# Pos [{'портал': 1}] Neg [{'услуг по сопровожден': 1}]
# 1 Оказание услуг комплексного сервиса обеспечения функционирования регионального сегмента единой государственной информационной системы в сфере здравоохранения в Ростовской области (РС ЕГИСЗ)
# Pos [] Neg []
# 1 Оказание услуг на обслуживание лабораторной информационной системы
# Pos [] Neg []
# 1 Оказание услуг на объекте информатизации, подключенном к информационной системе персональных данных Министерства образования, науки и молодежной политики Краснодарского края, в целях подключения к защищенной сети передачи данных № 3608
# Pos [] Neg []
# 1 Оказание услуг на разработку интеграционных сервисов и структурированных электронных медицинских документов в лабораторную информационную систему «АльфаЛАБ» для отправки в сервис «Реестр электронных медицинских документов» Единой государственной информационной системы в сфере здравоохранения
# Pos [] Neg []
# 1 Оказание услуг по адаптации описания цифрового образовательного контента для обучающихся с нарушением зрения (слабовидящих) по предмету «Основы безопасности жизнедеятельности» для 10-11 классов
# Pos [{'контент': 1}] Neg [{'услуг по адапт': 1}]
# 1 Оказание услуг по адаптации описания цифрового образовательного контента для обучающихся с нарушением слуха (слабослышащих) по предмету «Основы безопасности жизнедеятельности» для 10-11 классов
# Pos [{'контент': 1}] Neg [{'услуг по адапт': 1}]
# 1 Оказание услуг по адаптации описания цифрового образовательного контента для обучающихся с расстройствами аутистического спектра по предмету «Основы безопасности жизнедеятельности» для 10-11 классов
# Pos [{'контент': 1}] Neg [{'услуг по адапт': 1}]
# 1 Оказание услуг по визуализации геопространственной информации по объекту г. Вологда посредством создания технологического 3D-геопортала
# Pos [{'портал': 1}] Neg []
# 1 Разработка Программы оперативного, сезонного и специального технического обслуживания воздушного судна Ил-76ТД
# Pos [{'разработка': 1}] Neg [{'технического обслуживани': 1}]
# 1 Оказание услуг по созданию (развитию) и внедрению элементов интеллектуальной транспортной системы Новосибирской агломерации, предусматривающей автоматиза-цию процессов управления дорожным движением на территории городского округа Новосибирск, с приобретением и установкой оборудования, а также доступа к пред-установленному программному обеспечению для функционирования информационных систем (муниципальный уровень ИТС - Новосибирский городской округ)
# Pos [] Neg []
# 1 Оказание услуг по разработке программного обеспечения в части создания корпоративного портала с использованием отечественного ПО
# Pos [{'портал': 1}] Neg []
# 1 оказание услуг по созданию (разработке) нового официального сайта Государственного Собрания Республики Мордовия
# Pos [] Neg []
# 1 Поставка системы распознания автомобильных номеров
# Pos [] Neg []
# 1 Оказание услуг по разработке и развертыванию программного комплекса по учету и паспортизации электросетевого оборудования  Заказчика
# Pos [] Neg []
# 1 Услуги по созданию информационного портала сервисов молодежных пространств
# Pos [{'портал': 1}] Neg []
# 1 Поставка системы распознания автомобильных номеров
# Pos [] Neg []
# 1 Оказание услуг по созданию и обслуживанию интернет сайта
# Pos [] Neg []
# 1 Услуги по разработке программного обеспечения «Информационная система сбора данных по работе в зоне СПС»
# Pos [] Neg []
# 1 Оказание услуг по разработке информационного портала "Туристический сертификат"
# Pos [{'портал': 1}] Neg [{'сертификат': 1}]
# 1 Оказание услуг по разработке модуля информационной системы "Электронное издательство" для сбора статистик Телеграм каналов изданий
# Pos [] Neg []
# 1 Оказание услуг по организации интеллектуального мониторинга соблюдения этических норм и деонтологии в медицинских учреждениях Министерства здравоохранения Московской области
# Pos [] Neg []
# 1 Программная система интеллектуального анализа данных (Data Mining)
# Pos [] Neg []
# 1 Оказание услуг по разработке  сайта bashapteka.ru
# Pos [{'разработке сайта': 1}] Neg []
# 1 Оказание услуг по созданию (разработке) нового официального сайта Законодательного Собрания Ростовской области
# Pos [] Neg []
# 1 Программная система интеллектуального анализа данных (Data Mining)
# Pos [] Neg []
# 1 Услуги по проведению обследования информационных систем персональных данных и разработке документации на реализацию комплексной системы защиты персональных данных
# Pos [] Neg []
# 1 Оказание услуг по разработке программного обеспечения "Личный кабинет недропользователя" для Министерства природопользования и экологии Владимирской области.
# Pos [{'личный кабинет': 1}, {'личный кабинет': 1}] Neg []
# 1 Услуги по переносу контентной информации с текущего сайта администрации Фурмановского муниципального района на платформу "ГосВеб"
# Pos [{'контент': 1}] Neg []
# 1 Оказание услуг по разработке сервиса информационного взаимодействия ИС ЕКЖ с платформой «Молодая Арктика» для расширения функциональных возможностей организации процесса выпуска, выдачи и обслуживания Единой карты жителя на территории Мурманской области
# Pos [] Neg []
# 1 услуги по разработке образовательного Web-сайта Заказчика в соответствии с техническим заданием к договору.
# Pos [] Neg []
# 1 оказание услуг по сопровождению программных механизмов подсистемы «Приемная комиссия» в части обработок и отчетов, а также веб-сайта «Рейтинг абитуриента ВГТУ»
# Pos [{'веб': 1}, {'веб': 1}] Neg [{'услуг по сопровожден': 1, 'сопровождению программ': 1, 'опровождению программ': 1}]
# 1 Услуги по поисковой оптимизации и социальному продвижению сайта услуги (модернизация, редизайн)
# Pos [{'дизайн': 1}] Neg []
# 0 1. Оказание услуг по сопровождению автоматизированной системы «Адресная социальная помощь» и интегрируемых программных комплексов «Интеграция АС «АСП», с целью интеграции с «региональным порталом государственных и муниципальных услуг» и с «системой межведомственного электронного взаимодействия»: 1.1 предоставление права на использование программного обеспечения АСУПД «Тула» (регистрационный номер в ЕРРПО № 5251 от 29.04.2016, Свидетельство о государственной регистрации № 2014610425 от 09.01.2014) включая обновления и дополнительные функциональные возможности программного обеспечения, на условиях предоставления простой (неисключительной) лицензии; 1.2 предоставление права на использование программного обеспечения Автоматизированной системы «Точка интеграции со СМЭВ и ПГУ» (регистрационный номер в ЕРРПО № 15795 от 05.12.2022) включая обновления и дополнительные функциональные возможности программного обеспечения, на условиях предоставления простой (неисключительной) лицензии.
# Pos [{'портал': 1}, {'интеграция': 1}, {'интеграция': 1}] Neg [{'лицензи': 2, 'услуг по сопровожден': 1, 'обновлен': 2}]
# 0 2023/244/226 Закупка услуг (услуги по программированию системы пульта контроля и управления охранно-пожарный "С2000М" Болид, созданию новых сценариев для исполнительных устройств, программирование релейных выходов, разделов и групп разделов, отрисовка приборов в АРМ «Орион» и комплексная проверка работоспособности систем автоматической пожарной сигнализации (АПС), системы оповещения и управления эвакуацией людей при пожаре (СОУЭ), системы противодымной вентиляции в ФГБНУ НИИР им. В.А. Насоновой)
# Pos [] Neg []
# 0 № 23 - ЭК 2 - 565: работы по созданию и внедрению интеграционной платформы (единой платформы управления транспортной системой), а также подсистемы светофорного управления и подсистемы мониторинга параметров транспортных потоков интеллектуальной транспортной системы Липецкой городской агломерации
# Pos [] Neg []
# 0 Выполнение работ по модификации и сопровождению базы данных установленной ранее используемой программы для ЭВМ ГрадИнфо
# Pos [{'базы данных': 1}] Neg [{'работ по модификац': 1}]
# 0 Техническая поддержка и сопровождение портала правовой информации
# Pos [{'портал': 1, 'сопровождение портала': 1}, {'сопровождение портала': 1}] Neg [{'техническая поддержк': 1}]
# 0 ЭА-№-13889/23 «Выполнение работ по разработке программного обеспечения "СЭД-Агент"»
# Pos [] Neg []
# 0 Услуги по разработке и внедрению модели автоматизации ЦСО и управленческого документооборота учреждения для нужд ЛОГБУЗ "ДКБ"
# Pos [] Neg []
# 0 Оказание услуг по созданию аналитической системы для опроса населения и мониторинга результатов прохождения опроса
# Pos [] Neg []
# 1 1117-р Оказание услуги по миграции автоматизированной информационной системы организации процесса выдачи специальных разрешений на движение крупногабаритных и (или) тяжеловесных транспортных средств по автомобильным дорогам общего пользования регионального и межмуниципального значения Смоленской области на сервер автоматизированной системы весового и габаритного контроля на дорогах регионального и межмуниципального значения Смоленской области
# Pos [] Neg []
# 1 № 23-ЭА-101 Работы по адаптации автоматизированной информационной системы ОБУ «УМФЦ Липецкой области» для предоставления услуг Социального фонда Российской Федерации
# Pos [] Neg []
# 1 Выполнение работ (оказание услуг) по доработке и поддержке CRM системы Битрикс24 Института общественных наук федерального государственного бюджетного образовательного учреждения высшего образования «Российская академия народного хозяйства и государственной службы при Президенте Российской Федерации»(73/223-ЭМ-23)
# Pos [{'crm': 1}] Neg [{'доработк': 1, 'бюджет': 1}]
# 1 Выполнение работ по корректировке электронной модели территориальной схемы в области обращения с отходами на территории Владимирской области.
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развитию государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки портала общественных обсуждения
# Pos [{'портал': 1}] Neg []
# 1 Выполнение работ по созданию информационных систем и по предоставлению доступа к сервисам «Конструктор правовых документов» и «Интерактивный калькулятор» для пользователей сайта ГБУ «Малый бизнес Москвы» (среди СМП и СОНО)
# Pos [] Neg []
# 1 Закупка на оказание информационно-технологических услуг для нужд АО «Одинцовская теплосеть» в 2023-2024 гг.
# Pos [] Neg []
# 1 Комплексные IT услуги для нужд ООО «Щекинская ГРЭС»
# Pos [] Neg []
# 1 Многофункциональная справочно-экспертная система
# Pos [] Neg []
# 1 Оказание услуг  по технической поддержке комплекса региональных информационных систем: - «Система межведомственного электронного взаимодействия Курской области»; - «Портал государственных и муниципальных услуг Курской области»; - «Система исполнения услуг Курской области»
# Pos [{'портал': 1}] Neg [{'технической поддержк': 1}]
# 1 Оказание услуг на информационно-технологические услуги информационных централизованных систем ГК "Росатом"
# Pos [] Neg []
# 1 Оказание услуг по комплексному сопровождению информационных систем и сервисов таможни
# Pos [] Neg []
# 1 Оказание услуг по разработке программного обеспечения
# Pos [] Neg []
# 1 Услуги по проектированию и разработке информационных технологий для прикладных задач и тестированию программного обеспечения
# Pos [] Neg []
# 1 Развитие государственной информационной системы обеспечения градостроительной деятельности Ульяновской области
# Pos [] Neg []
# 1 Оказание услуг по разработке интерактивного программного обеспечения и мультимедийного наполнения фото- и видеоматериалами
# Pos [{'мультимеди': 1}] Neg []
# 1 Оказание услуг по разработке системы графической идентификации для обновления главной страницы портала «СтроимПросто»
# Pos [{'портал': 1}] Neg [{'обновлен': 1}]
# 0 2024/9-14 Оказание услуг по мониторингу и реагированию на инциденты информационной безопасности для АО «Сетевая компания»
# Pos [] Neg []
# 0 208165_Выполнение работ по приведению системы обработки пакета документов для подготовки иска к сетевой организации в соответствие Методике МТ-259-1 АО «Мосэнергосбыт»
# Pos [] Neg []
# 0 А3-2/2023 выполнение работ по проведению аварийного восстановления данных, необходимых для стабильной работы, недопущению аварийных ситуаций и обеспечению возможности оперативного реагирования на технологические нарушения на объектах электросетевого хозяйства АО «МСК Энерго»
# Pos [] Neg []
# 0 В соответствии с описанием предмета закупки
# Pos [] Neg []
# 0 Оказание услуг в области информационных технологий
# Pos [] Neg []
# 0 Оказание услуг на базе центра обработки данных, включающих предоставление облачной инфраструктуры
# Pos [] Neg []
# 0 Услуги по созданию и внедрению информационной системы «Корпоративный портал» на основе Битрикс24
# Pos [{'портал': 1}] Neg []
# 3184 2864

# %%
with open('regs.txt', 'r') as f:
    keys = [line.strip() for line in f]
print(keys)
#keys = ['\\bис\\b', '\\bпк\\b']
text = 'пк1с пк: -1с-'
cnt = {}
for k in keys:
    if len(l:=re.findall(k, text))>0:
        cnt[l[0]]=len(l)      

print(cnt)
# Out:
# ['\\b1с\\b', '\\bпк\\b']
# {'1с': 1, 'пк': 1}

# %%
df_keys = pd.read_csv('key_words.csv',delimiter=';')
keys = df_keys[(df_keys.np==0)].key.to_list()
print(keys)
text = 'пк1с пк: -1с-'
cnt = {}
for k in keys:
    if len(l:=re.findall(k, text))>0:
        cnt[l[0]]=len(l)      

print(cnt)
# Out:
# ['континент', 'техническ\\w\\w поддержк', 'абонемент', 'доработк', 'защит\\w? информаци', 'консультаци', 'консультационны\\w? услуг', 'образование', 'образовательны\\w услуг', 'глонасс', '\\bgps\\b', 'бюджет', 'антивирус', 'контур', '(?:\\bмис\\b|медицинская информационная система)', 'мис ариадна', 'техэксперт', 'бд супа', 'технокад', 'omnicommonline', 'карант', 'парус', 'континент', 'оборудование', 'лицензи', 'неисключительны\\w? прав', 'аттестация', 'контур-фокус', 'сертификат', 'брест', 'vipnet', 'барс-здравоохранение', 'бит.управление медицинскими сервисами', 'autosat', 'varonis', 'гранд-смета', 'спарк', 'кодекс', 'иас контрагент', 'катарсис', 'статус-поставщик', '\\brosa\\b', 'labforce', 'enterprize', 'vizualization', 'businessstudio', 'прав\\w? использовани', 'консультантплюс', 'предоставлени. в аренд', 'услуг\\w? по сопровожден', 'услуг\\w? по содержани', 'Услуг\\w? по передач', 'услуг\\w? по подписк', 'услуг\\w? по поставк', 'продлени', 'техническо\\w{1,2} сопровождени', 'принтер', 'сервисно\\w{1,2} обслуживан', 'техническо\\w{1,2} обслуживани', 'поддержани. работоспособност', 'услуг\\w? по настройк', 'услуг\\w? связи', 'аслуг\\w? по адаптац', 'абонентско\\w{1,2} обслуживани', 'поставк. программного обеспечени', 'usergate', 'информационн\\w{2,3} поддержк', 'работ\\w? по установк', 'работ\\w? по монтаж', 'техническо\\w{1,2} освидетельствован', 'услуг\\w? по обслуживан', 'техническ\\w{1,2} поддержк', 'проектно-сметн', 'развити. подсистем', 'содержани. комплекс', '\\b1с\\b', '\\b1c\\b', 'информационн\\w{2,3} сопровожден', 'работ\\w? по обслуживан', 'работ\\w? по модернизац', 'работ\\w? по модификац', 'работ\\w? по развит', 'криптопро', 'консультант плюс', 'монтаж\\w? систем', 'диспетчеризац', 'аверс', 'обновлен', 'обслуживани. оборудован', 'информационн\\w{2,3} услуг', 'сопровождени. программ', 'услуг\\w? доступ', 'услуг\\w? мониторинг', 'услуг\\w? на предоставлен', 'услуг\\w? по абонентск', 'услуг\\w? по адапт', 'услуг\\w? по активац', 'услуг\\w? по администриров', 'услуг\\w? по активац', 'услуг\\w? по актуализ', 'услуг\\w? по анализ', 'услуг\\w? по аттестац', 'услуг\\w? по внедрен', 'опровождени. программ', 'услуг\\w? по установк', 'услуг\\w? по опубликован', 'услуг\\w? по эксплуатац', 'услуг\\w? по поддержк', 'услуг\\w? по сопровожден', 'услуг\\w? по рассылк', 'услуг\\w? по предоставлен', 'услуг\\w? по модернизац', 'адаптаци. систем', 'работ\\w? по настройк', 'работ\\w? по восстановлен', 'модернизаци. программ', 'модификаци. программ', 'обслуживани. программ', 'прав\\w? заключен', 'услуг\\w? по консультирован', 'услуг\\w? по расширен', 'поставк. программ', 'услуг\\w? по размещен', 'проведени. аттестац', 'приобретени. программ', 'услуг\\w? по развит', 'услуг\\w? по интеграц', 'услуг\\w? по обеспечен', 'услуг\\w? консульт', 'услуг по подключен', 'развити. программ', 'сервисному сопровожд', 'услуг по перенос', 'услуг по обеспечен', 'поставк. оборудован']
# {'1с': 1}

# %%
df_keys
# Out:
#    np  dest  cls     key
# 0   1     0    0  \b1с\b
# 1   1     0    0  \bпк\b

# %%
s = r'\'
# Out:
#   Cell In[174], line 1
#     s = r'\'
#         ^
# SyntaxError: unterminated string literal (detected at line 1)
