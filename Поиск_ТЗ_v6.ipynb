# %% [markdown]
# Техническое задание содержится в файле
# Документация.rar\ч. V Техничесая часть.docx

# %% [markdown]
# # 1. Поиск ТЗ в списке документации к закупке

# %%
# pip install bayoo-docx
# pip install aspose-zip
# pip install aspose-words
# pip install pdfplumber #Работа с .PDF

import os, shutil, sys, re
from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph
import aspose.zip as az
import aspose.words as aw
import pdfplumber
import pandas as pd

def doc2txt(path):
    doc = aw.Document(path).get_text()
    s = re.sub('[\x07\x0b\x13HYPERLINK]', ' ', doc).split('\r')
    return '\n'.join([i.strip() for i in s if len(i.strip())>0][1:-1]) 

def zip2dir(fname):
    # Загрузить архив
    with az.Archive(fname) as archive:
	    # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def rar2dir(fname):
    # Загрузить архив
    with az.rar.RarArchive(fname) as archive:
        # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def iter_block_items(parent):
    """
    Generate a reference to each paragraph and table child within *parent*,
    in document order. Each returned value is an instance of either Table or
    Paragraph. *parent* would most commonly be a reference to a main
    Document object, but also works for a _Cell object, which itself can
    contain paragraphs and tables.
    """
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    elif isinstance(parent, _Row):
        parent_elm = parent._tr
    else:
        raise ValueError("something's not right")
    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

def docx2txt(docx_file):
    document = Document(docx_file)
    text = []
    for block in iter_block_items(document):
        #print(block.text if isinstance(block, Paragraph) else '<table>')
        if isinstance(block, Paragraph):
            if len(block.text.strip()) > 0:
                text.append(block.text)
        elif isinstance(block, Table):
            for row in block.rows:
                row_data = []
                for cell in row.cells:
                    for paragraph in cell.paragraphs:
                        row_data.append(paragraph.text)
                text.append("\t".join(row_data))    
    return '\n'.join(text)

def pdf2txt(fname):
    with pdfplumber.open(fname) as pdf:
        if len(pdf.pages):
            text_o = ' '.join([
                page.extract_text() or '' for page in pdf.pages if page
            ])
    return text_o

def xlsx2txt(fname):
    return pd.read_excel(fname).to_string()

def to_txt(path):
    txt_from_files = {}
    for root, dirs, files in os.walk(path):
        #print(f'{root=}, {dirs=}, {files=}')
        for fn in files:
            ext = fn.split('.')[-1]
            ffn = os.path.join(root, fn)
            if ext=='doc':
                txt_from_files[ffn] = doc2txt(ffn)
            elif ext=='docx':
                txt_from_files[ffn] = docx2txt(ffn)
            elif ext=='txt':
                with open(ffn,'r') as f:
                    txt_from_files[ffn] = f.read()
            elif ext in [ 'xlsx']:
                txt_from_files[ffn] = xlsx2txt(ffn)
            elif ext=='rar':
                rar2dir(ffn)
            elif ext=='zip':
                zip2dir(ffn)
    return txt_from_files

def clear_temp(path_temp):# Очистка временной папки
    if os.path.exists(path_temp): 
        shutil.rmtree(path_temp)
    os.mkdir(path_temp)

def find_nearest_file(texts, keywords):
    '''
    На вход подается словарь вида имя файла: текст и список ключевых фраз в формате re
    Функция ищет по ключевым фразам в тексте наиболее близкий по содержанию файл
    На выходе имя найденного файла 
    '''
    closest_file = None
    max_count = 0
    for filename, text in texts.items():
        if len(text)>0: 
            if sum([len(re.findall (k, os.path.basename(filename).lower())) for k in keywords]): # Если найдены совпадения в названии файла
                return filename
            else:
                text = re.sub("[^а-я\n ]", "", text.lower()).strip() # оставляем только русские буквы и перевод строки
                cnt = sum([len(re.findall (k, text)) for k in keywords])
                distance = 0
                text = text.split('\n')
                if cnt: # если найдено хоть одно совпадение
                    for i,s in enumerate(text): # то ищем номера строк в которых эти ключи найдены
                        cnt = sum([len(re.findall (k, s)) for k in keywords])
                        if cnt:
                            distance += cnt/(i+1) # вычисляем дистанцию, чем дальше фраза от начала документа, тем меньше ее вес
                    if distance > max_count:
                        max_count = distance
                        closest_file = filename
                print(f'{distance=:0.3f}, {filename=}')
                    
    return closest_file

# ==================================================================
path_root = "C:/temp/"
path_temp = "temp"
keywords = [r"\bтехническ.. задан*",  "описание объекта закупки"]

if  not os.path.exists(path_root):
    print("Папка не существует")
    sys.exit()

dirs = next(os.walk(path_root))[1]
# dirs = ['0124600003224000028']
for path in dirs:
    clear_temp(path_temp)
    path = os.path.join(path_root, path)    
    txt_from_files = to_txt(path)
    txt_from_arch = to_txt(path_temp)
    if txt_from_arch:
        txt_from_files = txt_from_files | txt_from_arch
    #clear_temp(path_temp)
    file_tz = find_nearest_file(txt_from_files, keywords)
    if file_tz:
        print(f'Техническое задание из каталога {path} с наибольшей вероятностью содержится в файле: {file_tz}')
        print(txt_from_files[file_tz][:200])
    else:
        print(f'Техническое задание из каталога {path} не найдено')
    print()

    
for key, value in txt_from_files.items():
    if len(value)!=0:
        fn = os.path.basename(key)
        fn = '.'.join(fn.split('.')[:-1]) +'.txt'
        with open(os.path.join(path_temp, fn), 'w', encoding='utf-8') as f:
            f.write(value)
# Out:
# Техническое задание из каталога C:/temp/0123200000324000309 с наибольшей вероятностью содержится в файле: C:/temp/0123200000324000309\docs\Описание объекта закупки.docx.docx
# Техническое задание
# на оказание услуг по сопровождению государственной информационной системы обеспечения градостроительной деятельности Амурской области
# 1. ОБЩИЕ СВЕДЕНИЯ
# 1.1. Описание услуг
# 1.1.1.
#
# distance=0.000, filename='C:/temp/0124200000624000686\\docs\\Обоснование начальной (максимальной) цены контракта.docx'
# Техническое задание из каталога C:/temp/0124200000624000686 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000686\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# distance=0.000, filename='C:/temp/0124200000624000712\\docs\\Обоснование начальной (максимальной) цены контракта.docx'
# Техническое задание из каталога C:/temp/0124200000624000712 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000712\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# distance=0.000, filename='C:/temp/0124200000624000713\\docs\\Изменение.doc'
# distance=0.000, filename='C:/temp/0124200000624000713\\docs\\Обоснование начальной (максимальной) цены контракта.doc'
# Техническое задание из каталога C:/temp/0124200000624000713 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000713\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# Техническое задание из каталога C:/temp/0124200000624000741 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000741\Описание объекта закупки.doc
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# distance=0.000, filename='C:/temp/0124200000624000758\\docs\\Обоснование начальной (максимальной) цены контракта.docx'
# Техническое задание из каталога C:/temp/0124200000624000758 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000758\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# distance=0.000, filename='C:/temp/0124200000624000938\\docs\\Обоснование начальной (максимальной) цены контракта.docx'
# Техническое задание из каталога C:/temp/0124200000624000938 с наибольшей вероятностью содержится в файле: C:/temp/0124200000624000938\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# distance=0.085, filename='C:/temp/0124300001424000004\\docs\\Приложение  3-ПРОЕКТ КОНТРАКТА.docx'
# Техническое задание из каталога C:/temp/0124300001424000004 с наибольшей вероятностью содержится в файле: C:/temp/0124300001424000004\docs\Приложение 1- описание объекта закупки.doc
# Приложение 1
# Описание объекта закупки (Техническое задание)
# Наименование и описание объекта закупки (функциональные, технические и качественные характеристики, эксплуатационные характеристики объекта
#
# Техническое задание из каталога C:/temp/0124300009424000010 с наибольшей вероятностью содержится в файле: C:/temp/0124300009424000010\docs\Описание объекта закупки.docx
# Описание объекта закупки в соответствии со статьей 33 Федерального закона от 05 апреля 2013 года № 44-ФЗ «О контрактной системе в сфере закупок товаров, работ, услуг для обеспечения государственных и
#
# Техническое задание из каталога C:/temp/0124600003224000028 с наибольшей вероятностью содержится в файле: C:/temp/0124600003224000028\docs\1. Описание объекта закупки Похозяйка испр.doc
# Описание объекта закупки
# Наименование и описание объекта закупки (функциональные, технические и качественные характеристики, эксплуатационные характеристики объекта закупки (при необходимости)):
# 1.1.Н
#
# distance=0.000, filename='C:/temp/0126100001124000004\\docs\\05 Приложение №4 Требования к участнику закупки.docx'
# distance=0.038, filename='C:/temp/0126100001124000004\\docs\\06 Приложение №5 Требования к содержанию и составу заявки.docx'
# distance=0.000, filename='C:/temp/0126100001124000004\\docs\\07 Приложение №6 Образец декларации.docx'
# distance=0.000, filename='C:/temp/0126100001124000004\\docs\\Приложение по  НМЦК.xlsx'
# distance=0.138, filename='C:/temp/0126100001124000004\\docs\\Проект ГК КП.docx'
# Техническое задание из каталога C:/temp/0126100001124000004 с наибольшей вероятностью содержится в файле: C:/temp/0126100001124000004\docs\Техническое задание.docx
# ТЕХНИЧЕСКОЕ ЗАДАНИЕ
# Оказание услуг по сопровождению установленной версии Электронного периодического справочника «КонсультантПлюс»
# 1. Наименование услуг (предмет закупки): Оказание услуг по сопровожде
#
# distance=0.000, filename='C:/temp/0127200000224000770\\docs\\информация о заказчике.doc'
# distance=0.000, filename='C:/temp/0127200000224000770\\docs\\Обоснование начальной (максимальной) цены контракта.doc'
# Техническое задание из каталога C:/temp/0127200000224000770 с наибольшей вероятностью содержится в файле: C:/temp/0127200000224000770\docs\Описание объекта закупки.docx
# Приложение № 1 к Контракту
# от «____» _____2024 г. № _____
# ОПИСАНИЕ ОБЪЕКТА ЗАКУПКИ
#                Наименование услуг: оказание услуг по адаптации и сопровождению установленной у Заказчика справочной
#
# distance=0.000, filename='C:/temp/0127200000224000792\\docs\\информация о заказчике.doc'
# distance=0.000, filename='C:/temp/0127200000224000792\\docs\\Обоснование начальной (максимальной) цены контракта.xlsx'
# Техническое задание из каталога C:/temp/0127200000224000792 с наибольшей вероятностью содержится в файле: C:/temp/0127200000224000792\docs\Описание объекта закупки.docx
# Описание объекта закупки
# на услуги по адаптации и сопровождению экземпляров
# систем КонультантПлюс на основе специального лицензионного сервисного программного обеспечения, обеспечивающего совместимос
#
# Техническое задание из каталога C:/temp/0128200000124000495 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000495\docs\Приложение  2 Описание объекта закупки СМИ.docx
# Описание объекта закупки
# Техническое задание
# Код по классификатору ОКПД2: 63.91.11.000
# Тип объекта закупки: услуга
# Способ указания объема выполнения работ: 1
# № п/п	Параметры требований 	Конкретные тр
#
# distance=0.708, filename='C:/temp/0128200000124000521\\docs\\Приложение_№_2_-_описание_объекта_закупки[1].doc'
# distance=0.039, filename='C:/temp/0128200000124000521\\docs\\Приложение_№_3_-_требования_к_содержанию,_составу_заявки_на_участие_в_закупке_и_инструкция_по_ее_заполнению[2].doc'
# distance=0.000, filename='C:/temp/0128200000124000521\\docs\\Приложение_№_4_-_проект_контракта[1].doc'
# distance=0.000, filename='C:/temp/0128200000124000521\\docs\\Электронный документ, полученный из внешней системы.doc'
# Техническое задание из каталога C:/temp/0128200000124000521 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000521\docs\Приложение_№_2_-_описание_объекта_закупки[1].doc
# Приложение № 2
# к извещению о проведении электронного аукциона
# Описание объекта закупки
# Техническое задание
# Код по классификатору ОКПД2: 63.91.11.000
# Тип объекта закупки: услуга.
# Способ оказания услуг:
#
# distance=0.708, filename='C:/temp/0128200000124000522\\docs\\Приложение_№_2_-_описание_объекта_закупки[1].doc'
# distance=0.039, filename='C:/temp/0128200000124000522\\docs\\Приложение_№_3_-_требования_к_содержанию,_составу_заявки_на_участие_в_закупке_и_инструкция_по_ее_заполнению[1].doc'
# distance=0.000, filename='C:/temp/0128200000124000522\\docs\\Приложение_№_4_-_проект_контракта[1].doc'
# distance=0.000, filename='C:/temp/0128200000124000522\\docs\\Электронный документ, полученный из внешней системы.doc'
# Техническое задание из каталога C:/temp/0128200000124000522 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000522\docs\Приложение_№_2_-_описание_объекта_закупки[1].doc
# Приложение № 2
# к извещению о проведении электронного аукциона
# Описание объекта закупки
# Техническое задание
# Код по классификатору ОКПД2: 63.91.11.000
# Тип объекта закупки: услуга.
# Способ оказания услуг:
#
# distance=0.200, filename='C:/temp/0128200000124000648\\docs\\Приложение№1_к Извещению-ЭА_Расчет НМЦК_модернизация Проекта_1кв2024.docx'
# distance=0.547, filename='C:/temp/0128200000124000648\\docs\\Приложение№2_к Извещению-ЭА_Описание_ТЗ_Календарный план_ПроектСмарт_2024-1кв2024.docx'
# distance=0.132, filename='C:/temp/0128200000124000648\\docs\\Приложение№3_к Извещению-ЭА_Проект Смарт_Форма заявки и инструкци_1кв2024.docx'
# distance=0.283, filename='C:/temp/0128200000124000648\\docs\\Приложение№4_к Извещению-ЭА_Проект Контракта ПроектСмарт_2024 для ЭА.docx'
# Техническое задание из каталога C:/temp/0128200000124000648 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000648\docs\Приложение№2_к Извещению-ЭА_Описание_ТЗ_Календарный план_ПроектСмарт_2024-1кв2024.docx
# Приложение № 2
# к извещению о проведении
# электронного аукциона
# Описание объекта закупки
# Код по КТРУ или код (ы) по классификатору
# ОКПД2 (ОК 034-2014): 62.02.30.000, 58.29.50.000
# Тип объекта закупки:
#
# distance=0.400, filename='C:/temp/0128200000124000684\\docs\\2,1 Приложение 1 К ИЗВЕЩЕНИЮ ОБОСНОВАНИЕ НМЦК_ЭА.docx'
# distance=0.000, filename='C:/temp/0128200000124000684\\docs\\2,1,1 Приложение к ОБОСНОВАНИЮ НМЦК_ЭА.xlsx'
# Техническое задание из каталога C:/temp/0128200000124000684 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000684\docs\2,2 и 3,1 Приложене 2 К ИЗВЕЩЕНИЮ ОПИСАНИЕ ОБЪЕКТА ЗАКУПКИ и ТЕХНИЧЕСКОЕ ЗАДАНИЕ.docx
# Приложение № 2
# к извещению
# Техническое задание
# (Описание объекта закупки)
# ОКПД2 (ОК 034-2014): 62.02.30.000
# Тип объекта закупки: услуга
# № п/п	Параметры требований 	Конкретные требования
# 1	Наименован
#
# Техническое задание из каталога C:/temp/0128200000124000783 с наибольшей вероятностью содержится в файле: C:/temp/0128200000124000783\docs\Прил №2 Описание объекта закупки_ТЗ_ЭА.doc
# Приложение № 2
# к извещению
# ОПИСАНИЕ ОБЪЕКТА ЗАКУПКИ
# Техническое задание
# услуги по адаптации и сопровождению экземпляров Систем КонсультантПлюс (в том числе специальной копии Систем КонсультантПлюс), о
#
# distance=0.200, filename='C:/temp/0128200001624000002\\docs\\Приложение 1 обоснование НМЦК_ЭА.docx'
# distance=0.202, filename='C:/temp/0128200001624000002\\docs\\Приложение 3 Требование к содержанию заявки.docx'
# Техническое задание из каталога C:/temp/0128200001624000002 с наибольшей вероятностью содержится в файле: C:/temp/0128200001624000002\docs\Приложение №2 Техническое задание.docx
# Техническое задание
# на передачу неисключительных прав использования баз данных путем проведения электронного аукциона
# Предмет электронного аукциона: Оказание услуг по предоставлению неисключительного
#
# Техническое задание из каталога C:/temp/0128300006024000031 с наибольшей вероятностью содержится в файле: C:/temp/0128300006024000031\docs\приложение №1 - описание объекта закупки.docx
# Приложение №1 к извещению об осуществлении закупки
# У Т В Е Р Ж Д А Ю
# Директор МКУ «УАХО»
# _________/А.М. Филимонов
# «___»____________ 2024 г.
# М.П.
# Описание объекта закупки в соответствии со статьей 33 Ф
#
# Техническое задание из каталога C:/temp/tz1 с наибольшей вероятностью содержится в файле: C:/temp/tz1\6067-ЭА Приложение №1 к извещению (Описание объекта закупки).docx
# Утверждено в части «Описание объекта закупки»:
# Директор ГБУДО «Областной Центр
# дополнительного образования детей»
# ______________О.С. Растегняева
# Приложение № 1 к извещению
# (Реестровый номер 6067-ЭА/
#
# distance=0.167, filename='C:/temp/tz2\\ПП_32211941666.docx'
# distance=0.167, filename='C:/temp/tz2\\ПРС_32211941666.docx'
# distance=0.010, filename='temp\\ЗП_Нейросеть.zip\\Документация о закупке запрос предложений проект.docx'
# distance=0.196, filename='temp\\ЗП_Нейросеть.zip\\Извещение запрос предложений.doc'
# distance=0.222, filename='temp\\ЗП_Нейросеть.zip\\Приложение 1 - Техническое задание\\ТЗ_на_конкурс_НейросетьКСП.docx'
# distance=0.000, filename='temp\\ЗП_Нейросеть.zip\\Приложение 2 - Проект договора\\Проект договора возмездного оказания услуг_2-0.doc'
# distance=0.000, filename='temp\\ЗП_Нейросеть.zip\\Приложение 3 - Обоснование НМЦ\\Обоснование НМЦ.docx'
# distance=0.000, filename='temp\\ЗП_Нейросеть.zip\\Приложение 3 - Обоснование НМЦ\\Расчет НМЦ.xlsx'
# Техническое задание из каталога C:/temp/tz2 с наибольшей вероятностью содержится в файле: temp\ЗП_Нейросеть.zip\Приложение 1 - Техническое задание\ТЗ_на_конкурс_НейросетьКСП.docx
# УТВЕРЖДАЮ
# Заместитель генерального директора	по специальным проектам 	ПАО «Россети Северный Кавказ»
# ___________________ Л.В. Дианов	 «___» _______________ 2022 г.
# СОГЛАСОВАНО
# Исполняющий обязанности
#
# distance=0.373, filename='C:/temp/tz3\\IV_Техническая часть.docx'
# Техническое задание из каталога C:/temp/tz3 с наибольшей вероятностью содержится в файле: C:/temp/tz3\Описание объекта закупки.doc
# Описание объекта закупки
# Оказание услуг по адаптации и сопровождению установленных на судебных участках мировых судей Курской области экземпляров Систем КонсультантПлюс
# 1. Основные понятия:
# 1.1. Справ
#
# distance=0.000, filename='C:/temp/tz4\\Контракт_на_создание_сайта_п._версия(1).doc'
# distance=0.000, filename='C:/temp/tz4\\НМЦК[9].docx'
# distance=0.374, filename='C:/temp/tz4\\Описание_объекта_закупки_сайт-_Больница_св._Георгия_п._версия.docx'
# distance=0.000, filename='C:/temp/tz4\\Требование__для_создания_сайта.docx'
# Техническое задание из каталога C:/temp/tz4 с наибольшей вероятностью содержится в файле: C:/temp/tz4\Описание_объекта_закупки_сайт-_Больница_св._Георгия_п._версия.docx
# УТВЕРЖДАЮ
# Главный врач
# СПб ГБУЗ «Городская больница
# Святого Великомученика Георгия»
#  _____________ Стрижелецкий В.В.
# 30 января  2024 г
# 				        Описание объекта закупки
# (Техническое задание на разр
#
# distance=0.000, filename='C:/temp/z32413301283\\test.doc'
# distance=0.000, filename='C:/temp/z32413301283\\test.docx'
# distance=0.000, filename='C:/temp/z32413301283\\Извещение.doc'
# distance=0.000, filename='C:/temp/z32413301283\\Ответ_на_запрос.docx'
# distance=0.000, filename='temp\\Документация.rar\\анкета.xlsx'
# distance=0.002, filename='temp\\Документация.rar\\ч. I-III.docx'
# distance=0.035, filename='temp\\Документация.rar\\ч. IV Проект договора.docx'
# distance=0.221, filename='temp\\Документация.rar\\ч. V Техничесая часть.docx'
# distance=0.000, filename='temp\\Документация.rar\\ч. VI Обоснование НМЦ.docx'
# distance=0.000, filename='temp\\Техническое задание.zip\\test.docx'
# Техническое задание из каталога C:/temp/z32413301283 с наибольшей вероятностью содержится в файле: temp\Документация.rar\ч. V Техничесая часть.docx
# «УТВЕРЖДАЮ»
#
# _______________
# 	«___» ________________ 2024 г.
# ТЕХНИЧЕСКОЕ ЗАДАНИЕ
# НА ВНЕДРЕНИЕ СЕРВИСА «НЕЙРОСЕТЕВОГО АГЕНТА (НСА)»
# В ЗАОЧНОЕ ОБСЛУЖИВАНИЕ ПОТРЕБИТЕЛЕЙ ГК «РОССЕТИ»
# НА ГОРЯЧЕЙ ЛИНИ

# %%
import re

def search_keys(text, keys):
    '''
    Функция считает количество ключевых слов/фраз в тексте
    На входе - текст, список ключевых слов в виде списка фраз в формате regex
    На выходе - словарь с ключами и их количеством
    '''
    text =  text.lower().strip() # переводим в нижний регистр
    cnt= {l[0]:len(l) for k in keys if len(l:=re.findall(k, text))>0}       
    return cnt


neg_keys = [
    r"континент",
    r"техническая поддержка",
    r"абонемент",
    r"доработка",
    r"защита (информации)",
    r"консультации",
    r"консультационные услуги",
    r"образование",
    r"образовательные услуги",
    r"глонасс",
    r"gps",
    r"бюджет",
    r"антивирус",
    r"контур контур контур",
    r"(?:\bмис\b|медицинская информационная система)",
    r"мис ариадна",
    r"техэксперт",
    r"бд супа",
    r"технокад",
    r"omnicommonline",
    r"карант",
    r"парус",
    r"континент",
    r"оборудование",
    r"лицензия",
    r"неисключительные права",
    r"аттестация",
    r"контур-фокус",
    r"сертификат",
    r"брест",
    r"vipnet",
    r"барс-здравоохранение",
    r"бит.управление медицинскими сервисами",
    r"autosat",
    r"varonis",
    r"гранд-смета",
    r"спарк",
    r"кодекс",
    r"иас контрагент",
    r"катарсис",
    r"статус-поставщик",
    r"rosa",
    r"labforce",
    r"enterprize",
    r"vizualization",
    r"businessstudio",
    r"право использования"
    ]
pos_keys = [
    r"(?:созда|разработ)[а-я]{2,3} сайт\w*",
    r"(?:созда|разработ)[а-я]{2,3} мобильн[а-я]{2,3} приложени\w*",
    r"(?:созда|разработ)[а-я]{2,3} пользовательск[а-я]{2,3} интерфейс\w*",
    r"(?:созда|разработ)[а-я]{2,3} нейросет\w*",
    r"(?:созда|разработ)[а-я]{2,3} алгоритм\w* анализа данных",
    r"(?:созда|разработ)[а-я]{2,3} архитектур\w* приложен\w*",
    r"(?:созда|разработ)[а-я]{2,3} дашборд\w*",
    r"(?:созда|разработ)[а-я]{2,3} микросервис\w*",
    r"(?:созда|разработ)[а-я]{2,3} механизм\w* аутентификац\w*",
    r"интегрирова[а-я]{2,3} внешн[а-я]{2,3} сервис\w*",
    r"интегрирова[а-я]{2,3} систем\w? аналитики и мониторинг\w?",
    r"автоматиз[а-я]{4,7} бизнес-процесс",
    r"провести тестирование производительности и безопасности",
    r"оптимиз[а-я]{4,7} код\w*",
    r"оптимиз[а-я]{4,7} интерфейс\w*",
    r"оптимиз[а-я]{4,7} запрос\w*",
    r"развер[а-я]{4,7} приложени\w на сервер\w*",
    r"провести аудит и рефакторинг кода",
    r"емейл-маркетинг",
    r"автоматизация процессов",
    r"сопровождение портала",
    r"актуализация документации",
    r"информационное сопровождение",
    r"smm-сопровождение",
    r"обработка данных",
    r"размещение материалов",
    r"реклама",
    r"размещение информации",
    r"предоставление хостинга",
    r"мониторинг сми",
    r"контент",
    r"маркетинговые услуги",
    r"продвижение в социальных сетях",
    r"базы данных",
    r"аналитическое сопровождение",
    r"мониторинг",
    r"контент-маркетинг",
    r"веб-разработка",
    r"рекламные услуги",
    r"информационное обслуживание",
    r"информационная кампания",
    r"облачные сервисы",
    r"электронная база данных",
    r"мультимедийные услуги",
    r"анализ данных",
    r"сетевое издание",
    r"цифровой образовательный ресурс",
    r"модернизация сайтов",
    r"онлайн-продажи",
    r"искусственный интеллект",
    r"портал",
    r"автоматизация",
    r"сервис",
    r"информационная система",
    r"агрегатор",
    r"личный кабинет",
    r"онлайн",
    r"анализ",
    r"логотип",
    r"лэндинг сайт",
    r"ведение соцсетей",
    r"интернет магазин",
    r"промо-сайт",
    r"интеграция",
    r"сервис",
    r"интернет ресурс",
    r"естественная речь",
    r"естественный язык",
    r"машинное обучение",
    r"\bml\b",
    r"\bai\b",
    r"\bcrm\b",
    r"биг-дата",
    r"бигдата",
    r"интернет",
    r"компьютерное зрение",
    r"devops",
    r"данные",
    r"разработка",
    r"приложение",
    r"фронтенд",
    r"бэкенд",
    r"маркетинг",
    r"веб-сервисы",
    r"веб-аналитика"
    ]

with open(r'C:\Users\user\Documents\python\1t\temp\ч. V Техничесая часть.txt', 'r', encoding='utf-8') as f:
    text = f.read()
pos_cnt = search_keys(text, pos_keys)
neg_cnt = search_keys(text, neg_keys)
print(f'Всего слов-маркеров {sum(pos_cnt.values())}:')
print(*[f'{k}({v})' for k,v in pos_cnt.items()], sep=', ')
print(f'Всего стоп-слов {sum(neg_cnt.values())}:')
print(*[f'{k}({v})' for k,v in neg_cnt.items()], sep=', ')
# Out:
# Всего слов-маркеров 105:
# автоматизирующее бизнес-процесс(1), контент(1), мониторинг(1), портал(6), сервис(65), информационная система(1), личный кабинет(3), онлайн(1), анализ(8), интеграция(3), ai(1), интернет(8), данные(2), разработка(3), приложение(1)
# Всего стоп-слов 6:
# техническая поддержка(1), консультации(1), образование(1), антивирус(1), лицензия(1), сертификат(1)
