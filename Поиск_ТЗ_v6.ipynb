# %% [markdown]
# Техническое задание содержится в файле
# Документация.rar\ч. V Техничесая часть.docx

# %% [markdown]
# # 1. Поиск ТЗ в списке документации к закупке

# %%
# pip install bayoo-docx
# pip install aspose-zip
# pip install aspose-words
# pip install pdfplumber #Работа с .PDF

import os, shutil, sys, re
from docx import Document
from docx.document import Document as _Document
from docx.oxml.text.paragraph import CT_P
from docx.oxml.table import CT_Tbl
from docx.table import _Cell, Table
from docx.text.paragraph import Paragraph
import aspose.zip as az
import aspose.words as aw
import pdfplumber
import pandas as pd

def doc2txt(path):
    doc = aw.Document(path).get_text()
    s = re.sub('[\x07\x0b\x13HYPERLINK]', ' ', doc).split('\r')
    return '\n'.join([i.strip() for i in s if len(i.strip())>0][1:-1]) 

def zip2dir(fname):
    # Загрузить архив
    with az.Archive(fname) as archive:
	    # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def rar2dir(fname):
    # Загрузить архив
    with az.rar.RarArchive(fname) as archive:
        # Извлечь файл 
        fn = os.path.basename(fname)
        archive.extract_to_directory(os.path.join(path_temp, fn))

def iter_block_items(parent):
    """
    Generate a reference to each paragraph and table child within *parent*,
    in document order. Each returned value is an instance of either Table or
    Paragraph. *parent* would most commonly be a reference to a main
    Document object, but also works for a _Cell object, which itself can
    contain paragraphs and tables.
    """
    if isinstance(parent, _Document):
        parent_elm = parent.element.body
    elif isinstance(parent, _Cell):
        parent_elm = parent._tc
    elif isinstance(parent, _Row):
        parent_elm = parent._tr
    else:
        raise ValueError("something's not right")
    for child in parent_elm.iterchildren():
        if isinstance(child, CT_P):
            yield Paragraph(child, parent)
        elif isinstance(child, CT_Tbl):
            yield Table(child, parent)

def docx2txt(docx_file):
    document = Document(docx_file)
    text = []
    for block in iter_block_items(document):
        #print(block.text if isinstance(block, Paragraph) else '<table>')
        if isinstance(block, Paragraph):
            if len(block.text.strip()) > 0:
                text.append(block.text)
        elif isinstance(block, Table):
            for row in block.rows:
                row_data = []
                for cell in row.cells:
                    for paragraph in cell.paragraphs:
                        row_data.append(paragraph.text)
                text.append("\t".join(row_data))    
    return '\n'.join(text)

def pdf2txt(fname):
    with pdfplumber.open(fname) as pdf:
        if len(pdf.pages):
            text_o = ' '.join([
                page.extract_text() or '' for page in pdf.pages if page
            ])
    return text_o

def xlsx2txt(fname):
    return pd.read_excel(fname).to_string()

def to_txt(path):
    txt_from_files = {}
    for root, dirs, files in os.walk(path):
        #print(f'{root=}, {dirs=}, {files=}')
        for fn in files:
            ext = fn.split('.')[-1]
            ffn = os.path.join(root, fn)
            if ext=='doc':
                txt_from_files[ffn] = doc2txt(ffn)
            elif ext=='docx':
                txt_from_files[ffn] = docx2txt(ffn)
            elif ext=='txt':
                with open(ffn,'r') as f:
                    txt_from_files[ffn] = f.read()
            elif ext in [ 'xlsx']:
                txt_from_files[ffn] = xlsx2txt(ffn)
            elif ext=='rar':
                rar2dir(ffn)
            elif ext=='zip':
                zip2dir(ffn)
    return txt_from_files

def clear_temp(path_temp):# Очистка временной папки
    if os.path.exists(path_temp): 
        shutil.rmtree(path_temp)
    os.mkdir(path_temp)

def find_nearest_file(texts, keywords):
    '''
    На вход подается словарь вида имя файла: текст и список ключевых фраз в формате re
    Функция ищет по ключевым фразам в тексте наиболее близкий по содержанию файл
    На выходе имя найденного файла 
    '''
    closest_file = None
    max_count = 0
    for filename, text in texts.items():
        if len(text)>0: 
            if sum([len(re.findall (k, os.path.basename(filename).lower())) for k in keywords]): # Если найдены совпадения в названии файла
                return filename
            else:
                text = re.sub("[^а-я\n ]", "", text.lower()).strip() # оставляем только русские буквы и перевод строки
                cnt = sum([len(re.findall (k, text)) for k in keywords])
                distance = 0
                text = text.split('\n')
                if cnt: # если найдено хоть одно совпадение
                    for i,s in enumerate(text): # то ищем номера строк в которых эти ключи найдены
                        cnt = sum([len(re.findall (k, s)) for k in keywords])
                        if cnt:
                            distance += cnt/(i+1) # вычисляем дистанцию, чем дальше фраза от начала документа, тем меньше ее вес
                    if distance > max_count:
                        max_count = distance
                        closest_file = filename
                print(f'{distance=:0.3f}, {filename=}')
                    
    return closest_file

# ==================================================================
path_root = "C:/temp/"
path_temp = "temp"
keywords = [r"\bтехническ.. задан*",  "описание объекта закупки"]

if  not os.path.exists(path_root):
    print("Папка не существует")
    sys.exit()

dirs = next(os.walk(path_root))[1]
# dirs = ['0124600003224000028']
for path in dirs:
    clear_temp(path_temp)
    path = os.path.join(path_root, path)    
    txt_from_files = to_txt(path)
    txt_from_arch = to_txt(path_temp)
    if txt_from_arch:
        txt_from_files = txt_from_files | txt_from_arch
    #clear_temp(path_temp)
    file_tz = find_nearest_file(txt_from_files, keywords)
    if file_tz:
        print(f'Техническое задание из каталога {path} с наибольшей вероятностью содержится в файле: {file_tz}')
        print(txt_from_files[file_tz][:200])
    else:
        print(f'Техническое задание из каталога {path} не найдено')
    print()

    
for key, value in txt_from_files.items():
    if len(value)!=0:
        fn = os.path.basename(key)
        fn = '.'.join(fn.split('.')[:-1]) +'.txt'
        with open(os.path.join(path_temp, fn), 'w', encoding='utf-8') as f:
            f.write(value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       1 # pip install bayoo-docx
#       2 # pip install aspose-zip
#       3 # pip install aspose-words
#       4 # pip install pdfplumber #Работа с .PDF
#       6 import os, shutil, sys, re
# ----> 7 from docx import Document
#       8 from docx.document import Document as _Document
#       9 from docx.oxml.text.paragraph import CT_P
#
# ModuleNotFoundError: No module named 'docx'

# %% [markdown]
# # Подсчет ключевых слов в тексте

# %%
import re

def search_keys(text, keys):
    '''
    Функция считает количество ключевых слов/фраз в тексте
    На входе - текст, список ключевых слов в виде списка фраз в формате regex
    На выходе - словарь с ключами и их количеством
    '''
    text =  text.lower().strip() # переводим в нижний регистр
    cnt= {l[0]:len(l) for k in keys if len(l:=re.findall(k, text))>0}       
    return cnt


neg_keys = [
    r"континент",
    r"техническая поддержка",
    r"абонемент",
    r"доработка",
    r"защита (информации)",
    r"консультации",
    r"консультационные услуги",
    r"образование",
    r"образовательные услуги",
    r"глонасс",
    r"gps",
    r"бюджет",
    r"антивирус",
    r"контур контур контур",
    r"(?:\bмис\b|медицинская информационная система)",
    r"мис ариадна",
    r"техэксперт",
    r"бд супа",
    r"технокад",
    r"omnicommonline",
    r"карант",
    r"парус",
    r"континент",
    r"оборудование",
    r"лицензия",
    r"неисключительные права",
    r"аттестация",
    r"контур-фокус",
    r"сертификат",
    r"брест",
    r"vipnet",
    r"барс-здравоохранение",
    r"бит.управление медицинскими сервисами",
    r"autosat",
    r"varonis",
    r"гранд-смета",
    r"спарк",
    r"кодекс",
    r"иас контрагент",
    r"катарсис",
    r"статус-поставщик",
    r"rosa",
    r"labforce",
    r"enterprize",
    r"vizualization",
    r"businessstudio",
    r"право использования"
    ]
pos_keys = [
    r"(?:созда|разработ)[а-я]{2,3} сайт\w*",
    r"(?:созда|разработ)[а-я]{2,3} мобильн[а-я]{2,3} приложени\w*",
    r"(?:созда|разработ)[а-я]{2,3} пользовательск[а-я]{2,3} интерфейс\w*",
    r"(?:созда|разработ)[а-я]{2,3} нейросет\w*",
    r"(?:созда|разработ)[а-я]{2,3} алгоритм\w* анализа данных",
    r"(?:созда|разработ)[а-я]{2,3} архитектур\w* приложен\w*",
    r"(?:созда|разработ)[а-я]{2,3} дашборд\w*",
    r"(?:созда|разработ)[а-я]{2,3} микросервис\w*",
    r"(?:созда|разработ)[а-я]{2,3} механизм\w* аутентификац\w*",
    r"интегрирова[а-я]{2,3} внешн[а-я]{2,3} сервис\w*",
    r"интегрирова[а-я]{2,3} систем\w? аналитики и мониторинг\w?",
    r"автоматиз[а-я]{4,7} бизнес-процесс",
    r"провести тестирование производительности и безопасности",
    r"оптимиз[а-я]{4,7} код\w*",
    r"оптимиз[а-я]{4,7} интерфейс\w*",
    r"оптимиз[а-я]{4,7} запрос\w*",
    r"развер[а-я]{4,7} приложени\w на сервер\w*",
    r"провести аудит и рефакторинг кода",
    r"емейл-маркетинг",
    r"автоматизация процессов",
    r"сопровождение портала",
    r"актуализация документации",
    r"информационное сопровождение",
    r"smm-сопровождение",
    r"обработка данных",
    r"размещение материалов",
    r"реклама",
    r"размещение информации",
    r"предоставление хостинга",
    r"мониторинг сми",
    r"контент",
    r"маркетинговые услуги",
    r"продвижение в социальных сетях",
    r"базы данных",
    r"аналитическое сопровождение",
    r"мониторинг",
    r"контент-маркетинг",
    r"веб-разработка",
    r"рекламные услуги",
    r"информационное обслуживание",
    r"информационная кампания",
    r"облачные сервисы",
    r"электронная база данных",
    r"мультимедийные услуги",
    r"анализ данных",
    r"сетевое издание",
    r"цифровой образовательный ресурс",
    r"модернизация сайтов",
    r"онлайн-продажи",
    r"искусственный интеллект",
    r"портал",
    r"автоматизация",
    r"сервис",
    r"информационная система",
    r"агрегатор",
    r"личный кабинет",
    r"онлайн",
    r"анализ",
    r"логотип",
    r"лэндинг сайт",
    r"ведение соцсетей",
    r"интернет магазин",
    r"промо-сайт",
    r"интеграция",
    r"сервис",
    r"интернет ресурс",
    r"естественная речь",
    r"естественный язык",
    r"машинное обучение",
    r"\bml\b",
    r"\bai\b",
    r"\bcrm\b",
    r"биг-дата",
    r"бигдата",
    r"интернет",
    r"компьютерное зрение",
    r"devops",
    r"данные",
    r"разработка",
    r"приложение",
    r"фронтенд",
    r"бэкенд",
    r"маркетинг",
    r"веб-сервисы",
    r"веб-аналитика"
    ]

with open(r'/mnt/c/temp/z32413301283/ч. V Техничесая часть.txt', 'r') as f: # , encoding='utf-8'
    text = f.read()
pos_cnt = search_keys(text, pos_keys)
neg_cnt = search_keys(text, neg_keys)
print(f'Всего слов-маркеров {sum(pos_cnt.values())}:')
print(*[f'{k}({v})' for k,v in pos_cnt.items()], sep=', ')
print(f'Всего стоп-слов {sum(neg_cnt.values())}:')
print(*[f'{k}({v})' for k,v in neg_cnt.items()], sep=', ')

# %%
# Классификация по теме закупки

# %%
import pandas as pd
import re

def search_keys(text, keys):
    '''
    Функция считает количество ключевых слов/фраз в тексте
    На входе - текст, список ключевых слов в виде списка фраз в формате regex
    На выходе - словарь с ключами и их количеством
    '''
    text =  text.lower().strip() # переводим в нижний регистр
    cnt= {l[0]:len(l) for k in keys if len(l:=re.findall(k, text))>0}       
    return cnt

work_class = {
    0:'Веб-разработка',
    1:'Дизайн',
    2:'Маркетинг',
    3:'Системный и бизнес анализ',
    4:'Тестирование',
    5:'Data science',
    6:'Беспилотники'
}
work_role = {
    0:'Подходит СОЮЗу',
    1:'Подходит СОЮЗу с поддержкой 1Т',
    2:'Не подходит СОЮЗу'
}

df_keys = pd.read_csv('key_words.csv',delimiter=';')
df_db = pd.read_csv('/mnt/c/temp/df_pp_stem_lemm.csv')
# df_db[df_db.sentiment!=0].loc[:,['sentiment','name']]
db = []
for idx,row in df_db.iterrows():
    db.append({}) 
    # Находим индекс последнего элемента
    li = len(db) - 1
    db[li]['target']=row['sentiment']
    db[li]['name_z']=row['name']
    db[li]['neg_keys']=[]
    db[li]['pos_keys']=[]
    # Negative keys
    keys = df_keys[(df_keys.np==0)].key.to_list()
    text =  row['name'].lower().strip() # переводим в нижний регистр
    cnt = search_keys(text, keys) 
    if len(cnt) > 0:
        db[li]['neg_keys'].append(cnt)
    # Positive keys
    for dest in df_keys[df_keys.np==1].dest.unique():
        for cl in df_keys[(df_keys.np==1) & (df_keys.dest==dest)].cls.unique():
            keys = df_keys[(df_keys.np==1) & (df_keys.dest==dest) & (df_keys.cls==cl)].key.to_list()
            text =  row['name'].lower().strip() # переводим в нижний регистр
            cnt = search_keys(text, keys) 
            if len(cnt) > 0:
                db[li]['pos_keys'].append(cnt)

for d  in db:
    if  not (len(d['pos_keys'])==0 and len(d['neg_keys'])>0 and d['target']==0):
        print(d['target'], d['name_z'])
        print('Pos', d['pos_keys'], 'Neg', d['neg_keys'])
# Out:
# 0   Предоставление неисключительного права использования антивирусного программного обеспечения Kaspersky Endpoint Security для бизнеса - Стандартный Russian Edition
# Pos [] Neg []
# 0  Предоставление услуг по сопровождению программного комплекса на платформе «1С»
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Программное средство антивирусной защиты
# Pos [] Neg []
# 0  Услуги по предоставлению в аренду серверных мощностей  для размещения на них программных продуктов семейства 1С Бухгалтерия и информационно -технологическому сопровождению 1С.
# Pos [] Neg []
# 0 	Модернизация процессов управления автоматизированной системой диспетчерской службы скорой медицинской помощи, необходимые для создания структурированного электронного документа
# Pos [] Neg []
# 0 "ежемесячные услуги по обслуживанию, поддержке и информационно-консультативному сопровождению программных продуктов «1С: Предприятие 8» в составе: «1С: Бухгалтерия государственного учреждения», «1С: Зарплата и кадры бюджетного учреждения»
# Pos [] Neg []
# 0 "Оказание услуг по предоставлению сертификата на техническое сопровождение программных комплексов ViPNet Client"
# Pos [] Neg []
# 0 "Оказание услуги по предоставлению сертификата на техническую поддержку программного продукта «Парус-Бюджет 8»
# Pos [] Neg []
# 0 "Оказание услуги по содержанию и эксплуатации программно-аппаратного комплекса автоматизированной системы управления наружным освещением (далее – АСУНО) «Кулон» на действующей сети автомобильных дорог общего пользования федерального значения." (лот 121)
# Pos [] Neg []
# 0 (0870-р) Услуги по передаче неисключительных прав на модули
# Pos [] Neg []
# 0 (1161-р) Оказание услуг по техническому сопровождению региональной централизованной системы «Управление скорой и неотложной медицинской помощью (в том числе, санитарной авиацией)»
# Pos [] Neg []
# 0 «Оказание услуг по передаче неисключительных (пользовательских) лицензионных прав, сопровождению и технической поддержке программного обеспечения «Парус-Бюджет 8»»
# Pos [] Neg []
# 0 «ОКАЗАНИЕ УСЛУГ ПО ПЕРЕДАЧЕ СРОЧНЫХ НЕИСКЛЮЧИТЕЛЬНЫХ ЛИЦЕНЗИОННЫХ ПРАВ НА ПО «ЭКОНОМ-ЭКСПЕРТ. ДОГОВОРЫ", "ЭКОНОМ-ЭКСПЕРТ. ОНЛАЙН +РАСЧЁТ НМЦК ДЛЯ ЛЕКАРСТВЕННЫХ ПРЕПАРАТОВ, 6 РАБОЧИХ МЕСТ, 1 ЗАКАЗЧИК + СОПРОВОЖДЕНИЕ»
# Pos [] Neg []
# 0 «Оказание услуг по подписке 1С» для субъектов малого и среднего предпринимательства
# Pos [] Neg []
# 0 «Услуга по сопровождению и консультационной поддержке АИС «Имущество» в городском округе город Уфа Республики Башкортостан»
# Pos [] Neg []
# 0 1127-р Услуги по техническому освидетельствованию в целях списания компьютерной техники, оргтехники, и прочей техники
# Pos [] Neg []
# 0 13_Оказание услуг по информационно-техническому сопровождению программы «1С: Предприятие» уровня ИТС Бюджет ПРОФ для нужд Лениногорского филиала КНИТУ-КАИ
# Pos [] Neg []
# 0 14_Оказание услуг в области информационных технологий по продлению неисключительных (пользовательских) лицензионных прав электронной базы данных «Госфинансы»
# Pos [] Neg []
# 0 2023/244/226 Закупка услуг по развитию МИС Интерин
# Pos [] Neg []
# 0 2023/9-68 Оказание услуг по сопровождению автоматизированной системы «Управление и мониторинг электрозарядными станциями»
# Pos [] Neg []
# 0 2023/9-71 Предоставление неисключительного права на лицензии и сертификаты ViPNet, UserGate
# Pos [] Neg []
# 0 2023-09879 = Оказание услуг по адаптации и сопровождению экземпляров Систем КонсультантПлюс  на основе специального лицензионного программного обеспечения, обеспечивающего совместимость услуг с установленными у Заказчика экземплярами Систем КонсультантПлюс
# Pos [] Neg []
# 0 2023-10039 = Оказание услуг по информационному сопровождению систем «КонсультантПлюс»
# Pos [] Neg []
# 0 2023-10043 = Оказание информационных услуг по сопровождению и обновлению ранее установленных  у заказчика версий электронного периодического справочника «Система ГАРАНТ»
# Pos [] Neg []
# 0 2023-10395 = Оказание услуг по информационно-техническому сопровождению программы «1С Бухгалтерия государственного учреждения 2.0»
# Pos [] Neg []
# 0 2023-10657 Оказание услуг по предоставлению сертификатов на полную техническую поддержку ПО TrueConf
# Pos [] Neg []
# 0 2023-11200 = Оказание услуг по адаптации и сопровождению комплекта СПС КонсультантПлюс в 2024 году
# Pos [] Neg []
# 0 2023-11204 = Оказание услуг по передаче неисключительных лицензионных прав на использование антивирусного программного обеспечения
# Pos [] Neg []
# 0 2023-11341 = Оказание услуг по обслуживанию програмного обеспечения "1С:Бухгалтерия 8 ПРОФ" и "1С: Зарплата и управление персоналом"
# Pos [] Neg []
# 0 2023-11421 = Оказание услуг по сопровождению информационной базы на платформе «1С: Предприятие 8.3» (конфигурации «Зарплата и кадры государственного учреждения (ред. 3.1)», «Бухгалтерия государственного учреждения (ред. 2)», «Больничная аптека (ред. 2»)
# Pos [] Neg []
# 0 2023-11586 = Оказание услуг по адаптации и сопровождению экземпляров Систем КонсультантПлюс, оказываемых на основе специального лицензионного сервисного программного обеспечения, обеспечивающего совместимость (взаимодействие) услуг с ранее установленными у Государственного Заказчика экземплярами Систем КонсультантПлюс
# Pos [] Neg []
# 0 2023-11587 = Услуги по адаптации и сопровождению экземпляров Систем КонсультантПлюс, оказываемых на основе специального лицензионного сервисного программного обеспечения, обеспечивающего совместимость (взаимодействие) услуг с ранее установленными у Государственного Заказчика экземплярами систем КонсультантПлюс
# Pos [] Neg []
# 0 2024/9-10 Оказание услуг по сопровождению ИАС Контрагент
# Pos [] Neg []
# 0 2024/9-11 Оказание услуг по сопровождению справочников и услуг по сопровождению Системы управления мастер данными 1С МДМ
# Pos [] Neg []
# 0 2024/9-13 Предоставление права использования: ФСС "Система Финансовый директор", КСС "Система Кадры", ЭС "Госзаказ", ЭС "Охрана труда", ЮСС "Система Юрист",ЭС "Промбезопасность"
# Pos [] Neg []
# 0 2024/9-8 Оказание услуг по сопровождению ПО: Автоматизированная система учёта ресурсов (АСУР) электрической сети на базе программного продукта GE Smallworld Electric Office
# Pos [] Neg []
# 0 2024/9-9 Оказание услуг по сопровождению ПК Энергобилинг
# Pos [] Neg []
# 0 208471_«Покопийное обслуживание МФУ и принтеров для нужд АО «ТГК-11»»
# Pos [] Neg []
# 0 208540_ОЗП_Сервисное обслуживание ЭГСР ТА-3 СП ТЭЦ-3 для нужд АО «ТГК-11»
# Pos [] Neg []
# 0 208541_ОЗП_Сервисное обслуживание ЭГСР ТА-10 СП ТЭЦ-3 для нужд АО «ТГК-11»
# Pos [] Neg []
# 0 208588_Оказание информационных услуг по сопровождению системы Консультант плюс для нужд ООО «Северная сбытовая компания»
# Pos [] Neg []
# 0 208666_Техническое обслуживание технологического видеонаблюдения для Пермской ГРЭС
# Pos [] Neg []
# 0 23-101607 Передача неисключительных прав на использование программного средства антивирусной защиты
# Pos [] Neg []
# 0 23Т0410050.0013. Оказание услуг по поддержанию работоспособности и аварийному восстановлению оборудования цифровых АТС (АУ, СЭС, ЦЭС) для нужд Мурманского филиала ПАО «Россети Северо-Запад»
# Pos [] Neg []
# 0 265-ПЗЕИ/2023 Оказание услуг информационно- технологического сопровождения программного продукта «ИБР: Управление технологическими присоединениями 10»
# Pos [] Neg []
# 0 311/2023 Оказание услуг по настройке и квалификации сервера Openlab для нужд ФГБУ «НЦЭСМП» Минздрава России
# Pos [] Neg []
# 0 33/2023-ЕП Оказание услуг по настройке и внедрению программно-аппаратного комплекса UserGate C150
# Pos [] Neg []
# 0 № 103/24/25-КБ на оказание услуг связи по предоставлению доступа к сети передачи данных и использованию линий связи, передачу данных по каналам связи для нужд филиала ФГБУ ФСНКЦ  ФМБА России КБ № 42
# Pos [] Neg []
# 0 № 104/24/25-КБ на оказание услуг по информационному сопровождению Системы КонсультантПлюс, эксплуатируемой филиалом ФГБУ ФСНКЦ  ФМБА России КБ № 42
# Pos [] Neg []
# 0 № 15 Услуги по передаче неисключительных прав на установку и использование операционной системы специального назначения "Astra Linux Special Edition" для нужд АПОУ УР "ТРИТ ИМ. А.В. ВОСКРЕСЕНСКОГО"
# Pos [] Neg []
# 0 № 23-ЭА-107 Услуги по предоставлению сертификата технической поддержки системы управления базами данных Postgres Pro Certified
# Pos [] Neg []
# 0 № 2446-аэф//т Поставка программного обеспечения - системы виртуализации «РЕД Виртуализация» и предоставление неисключительных (пользовательских) прав на её использование
# Pos [] Neg []
# 0 № зз-30022-2023 Услуги по переходу с программного продукта 1С:Предприятие 7.7, Камин 1.2 на 1С:Бухгалтерия, ред.3.0, 1С:Зарплата и управление персоналом
# Pos [] Neg []
# 0 № зз-32008 - 2023 Услуги по адаптации и сопровождению экземпляров Систем ''Консультант Плюс'', включая специальную копию Систем
# Pos [] Neg []
# 0 № зз-33292-2023 Оказание услуг по обновлению специализированного программного средства «Учет бюджетных средств, предоставленных сельскохозяйственным товаропроизводителям в форме субсидий» в части обеспечения возможности подачи и обработки заявлений по девяти направлениям субсидирования в электронном виде
# Pos [] Neg []
# 0 № зз-33624-2023 Оказание услуг по поставке, установке и настройке оборудования криптографического узла комплекса защищенной сети
# Pos [] Neg []
# 0 № зз-34245-2023 Программное обеспечение, предназначенное для защиты приложений от несанкционированного доступа
# Pos [] Neg []
# 0 №240-ЭА/23/К "Оказание услуг по сопровождению компьютерных систем для нужд Клиники ФГБОУ ВО КубГМУ Минздрава России"
# Pos [] Neg []
# 0 №60754-2023-ЭА-2365 Оказание услуг на информационно-вычислительные услуги – абонентское и консультационное обслуживание средств автоматизации информационно-библиотечной деятельности АИБС «МАРК-SQL» версия с поддержкой RFID технологий и оказание услуг по предоставлению неисключительных прав на использование автоматизированной информационно-библиотечной системы
# Pos [] Neg []
# 0 №60908-2023-ЭА-2424 Подписка на информационно-техническое сопровождение программы «1С: КП ЦГУ»
# Pos [] Neg []
# 0 №60909-2023-ЭА-2431 Услуги по информационному сопровождению и консультативному обслуживанию программных продуктов «1С:Предприятие 8»: «1С:Бухгалтерия государственного учреждения 8», «1С:Зарплата и кадры государственного учреждения 8».
# Pos [] Neg []
# 0 №60962-2023-ЭА-2707 Оказание услуг по передаче сертификата активации сервиса технической поддержки Secret Net Studio
# Pos [] Neg []
# 0 №61082-2023-ЭА-2576 Услуги по предоставлению сертификата активации сервиса совместной технической поддержки ПАК ViPNeT Coordinator HW1000 4
# Pos [] Neg []
# 0 №61280-2023-ЭА-2644 Оказание услуг по предоставлению сертификата на техническую поддержку Кибер Бэкап для физического сервера
# Pos [] Neg []
# 0 №66 Оказание услуг по сопровождению Электронного периодического справочника «Система ГАРАНТ» для нужд бюджетного учреждения здравоохранения Удмуртской Республики «Республиканский кожно-венерологический диспансер Министерства здравоохранения Удмуртской Республики»
# Pos [] Neg []
# 0 Абонемент на предоставление доступа по сети Интернет к экземплярам информационно-справочных систем «Техэксперт» для филиала в СВАО
# Pos [] Neg []
# 0 Абонемент на предоставление доступа по сети Интернет к экземплярам профессиональных справочных систем «Техэксперт: Базовые нормативные документы. Лаборатория»
# Pos [] Neg []
# 0 Абонемент на техническое обслуживание Единой системы учета объектов и неналоговых доходов Краснодарского края (ЕСУОНД)
# Pos [] Neg []
# 0 Абонемент Технического обслуживания и дополнительного сопровождения технического обслуживания Единой системы учета объектов и неналоговых доходов в Краснодарском крае
# Pos [] Neg []
# 0 Абонентское обслуживание 1С
# Pos [] Neg []
# 0 Абонентское обслуживание информационных систем (сервера)
# Pos [] Neg []
# 0 Автоматизация процессов работы лаборатории
# Pos [] Neg []
# 0 Адаптация и сопровождение экземпляров Систем КонсультантПлюс
# Pos [] Neg []
# 0 Адаптация и сопровождение экземпляров систем КонсультантПлюс
# Pos [] Neg []
# 0 Адаптация и установка адаптированных баз данных, составляющих информационно-справочные системы «Техэксперт» (ИСС)
# Pos [] Neg []
# 0 Антивирус Dr.Web
# Pos [] Neg []
# 0 Аттестация объекта информатизации ПЭВМ на соответствие требованиям о защите  информации,содержащей сведения,составляющие государственную тайну (услуги в сфере ИКТ)
# Pos [] Neg []
# 0 Аукцион в электронной форме на право заключения контракта на оказание услуг по техническому сопровождению подсистемы "Мониторинга подвижных транспортных средств и специальной техники" автоматизированной системы управления производством и содержанием автомобильных дорог для нужд ГБУ "Автомобильные дороги" среди субъектов малого предпринимательства и социально ориентированных некоммерческих организаций
# Pos [] Neg []
# 0 Аукцион в электронной форме на право заключения контракта на поставку программного обеспечения для нужд ГБУ «Автомобильные дороги» среди субъектов малого предпринимательства и социально ориентированных некоммерческих организаций
# Pos [] Neg []
# 0 Аукцион в электронной форме открытым способом на оказание услуг по безвендорной технической поддержке программных продуктов Varonis
# Pos [] Neg []
# 0 В соответствии с условиями настоящего Договора "Исполнителем" передается "Заказчику" комплект лицензионного программного обеспечения UserGate (неисключительное, не подлежащее передаче или перепродаже право на использование  программного обеспечения) в объеме, установленном лицензионными соглашениями с правообладателями, состав которого определен спецификацией (Приложение №1 настоящего Договора), подписываемой одновременно с Договором и являющейся его неотъемлемой частью, а "Заказчик"  обязуется принять и оплатить поставляемое лицензионное программное обеспечение (право его использования).
# Pos [] Neg []
# 0 Внедрение и адаптация системы электронного документооборота "Дело" в администрации муниципального образования Белореченский район
# Pos [] Neg []
# 0 Внедрение программного продукта "1С: Зарплата и кадры государственного учреждения 8"
# Pos [] Neg []
# 0 Внедрение, адаптация и сопровождение программы ЭВМ и баз данных системы безналичной оплаты и учета питания в общеобразовательных учреждениях.
# Pos [] Neg []
# 0 Возмездное оказание услуг с использованием оборудования центра коллективного пользования уникальным аналитическим оборудованием “Дальневосточный вычислительный ресурс”
# Pos [] Neg []
# 0 Возмездное оказание услуг с использованием оборудования центра коллективного пользования уникальным аналитическим оборудованием “Дальневосточный вычислительный ресурс”
# Pos [] Neg []
# 0 Выбор Подрядчика на выполнение обязательств по монтажу видеонаблюдения, согласно сметному расчету, технического задания в МАУ «Центр культуры и досуга г. Улан-Удэ» по адресу: Республика Бурятия, г. Улан-Удэ, ул. Бабушкина 7. (цокольный этаж)
# Pos [] Neg []
# 0 Выполнение  работ по настройке и адаптации системы специального программного обеспечения в целях автоматизации процессов кадровых служб государственных учреждений
# Pos [] Neg []
# 0 Выполнение комплекс работ по расчету гидравлического режима,  параметров и наладке эксплуатационных режимов магистральной теплосети МУП «Шарьинская ТЭЦ»  на г. Шарья методом оптимизации потокораспределения теплоносителя при разделении магистралей от коллектора водогрейной котельной Шарьинской ТЭЦ
# Pos [] Neg []
# 0 Выполнение комплекса работ по адаптации, модификации и сопровождению  программного продукта «1С: Предприятие»
# Pos [] Neg []
# 0 Выполнение комплекса специальных работ по обследованию информационно-технологической инфраструктуры с приобретением программных средств защиты информации от несанкционированного доступа
# Pos [] Neg []
# 0 Выполнение работ по  внедрению подсистемы "Регламентированный и налоговый учет»  на базе программного продукта «1С:ERP. Управление предприятием 2» и модуля «1С.Производство алкогольной продукции» с расширением стандартной функциональности для отраслевой специфики предприятия
# Pos [] Neg []
# 0 Выполнение работ по  внедрению подсистемы "Финансовый результат и контроллинг»  на базе программного продукта «1С:ERP. Управление предприятием 2» и модуля «1С.Производство алкогольной продукции» с расширением стандартной функциональности для отраслевой специфики предприятия
# Pos [] Neg []
# 0 Выполнение работ по внедрению модуля информационного взаимодействия с ТФОМС Пензенской области и передаче лицензионных прав
# Pos [] Neg []
# 0 Выполнение работ по внедрению программного продукта 1С:Битрикс
# Pos [] Neg []
# 0 Выполнение работ по внедрению промышленной настройки и модели функционирования программного комплекса на базе конфигурации «Зарплата и управление персоналом 3.1» Сводного отчета по численности в целях формирования данных по Программе финансово-хозяйственной деятельности
# Pos [] Neg []
# 0 выполнение работ по восстановлению данных с цифрового носителя Заказчика
# Pos [] Neg []
# 0 Выполнение работ по диспетчеризации и автоматизация котельной №7 с.Муслюмово
# Pos [] Neg []
# 0 Выполнение работ по доработке и развитию автоматизированной информационной системы (АИС Москва.Река).
# Pos [] Neg []
# 0 Выполнение работ по доработке Информационной системы «Инфраструктура пространственных данных Приморского края» модуля «Сельское хозяйство»
# Pos [] Neg []
# 0 Выполнение работ по доработке Модуля ПАК САБП «Система электронного согласования договоров»
# Pos [] Neg []
# 0 Выполнение работ по доработке Модуля ПАК САБП «Электронный документооборот
# Pos [] Neg []
# 0 Выполнение работ по замене фискальных накопителей в ККТ и оказание услуг по предоставлению подписки на обработку и передачу фискальных данных ОФД. Предусмотрена подпунктом 30 пункта 1 раздела 2 главы IV Положения о закупке товаров, работ, услуг для нужд федерального государственного бюджетного образовательного учреждения высшего образования «Челябинский государственный университет», утвержденного Министерством науки и высшего образования Российской Федерации 15.04.2022.
# Pos [] Neg []
# 0 Выполнение работ по информационной поддержке Интегрированной информационной лабораторной системы ФГБУ «ИМЦЭУАОСМП» Росздравнадзора
# Pos [] Neg []
# 0 Выполнение работ по модернизации комплексов измерительных скорости движения транспортных средств фоторадарных "КРИС-П", "КРИС-П"М
# Pos [] Neg []
# 0 Выполнение работ по модернизации программной инфраструктуры  автоматизации медицинской и административной деятельности  при осуществлении лечебно-диагностических процессов
# Pos [] Neg []
# 0 Выполнение работ по модернизации программной инфраструктуры автоматизации медицинской и административной деятельности при осуществлении лечебно-диагностических процессов
# Pos [] Neg []
# 0 Выполнение работ по модернизации системы резервного копирования для создания распределенной системы резервного копирования Министерства финансов Чеченской Республики
# Pos [] Neg []
# 0 Выполнение работ по модернизации Системы электронного документооборота ФМБА России путем установки и адаптации программного обеспечения, включая предоставление права использования программного обеспечения для мобильных устройств на условиях простой (неисключительной) лицензии
# Pos [] Neg []
# 0 Выполнение работ по модернизации функциональных подсистем, контуров и информационных баз данных АИС «ЕСТР»
# Pos [] Neg []
# 0 Выполнение работ по модификации ПК "Здравоохранение" с целью подключения лабораторных анализаторов
# Pos [] Neg []
# 0 Выполнение работ по модификации программного комплекса «Региональная Медицинская Информационная Система»
# Pos [] Neg []
# 0 Выполнение работ по модификации программы для ЭВМ в целях развития региональной геоинформационной системы Самарской области
# Pos [] Neg []
# 0 Выполнение работ по монтажу структурированных компьютерных сетей
# Pos [] Neg []
# 0 Выполнение работ по настройке и модификации системы «1С:Документооборот»
# Pos [] Neg []
# 0 Выполнение работ по настройке нотификации в УСПО при изменении района в Системе обеспечения вызова экстренных оперативных служб по единому номеру «112» на территории Республики Коми.
# Pos [] Neg []
# 0 Выполнение работ по обслуживанию мультимедийного оборудования
# Pos [] Neg []
# 0 выполнение работ по обслуживанию программного продукта 1С предприятие 8
# Pos [] Neg []
# 0 Выполнение работ по переходу с информационной системы "1С Зарплата и управление персоналом 2.5 КОРП" в информационную систему "1С Зарплата и управление персоналом 3.1" для нужд ООО "Талдинское ПТУ"
# Pos [] Neg []
# 0 Выполнение работ по подготовке техно-рабочего проекта на доукомплектование интеллектуальной транспортной системы регионального уровня объектами муниципального значения
# Pos [] Neg []
# 0 Выполнение работ по проектированию единой информационной системы ФГУП ГЦСС на базе «1С:Предприятие 8» ERP для нужд ФГУП ГЦСС
# Pos [] Neg []
# 0 Выполнение работ по проектированию систем обеспечения информационной безопасности объектов информатизации для нужд филиала ФГУП ГЦСС
# Pos [] Neg []
# 0 Выполнение работ по производству аудиовизуальной продукции и трансляции в телеэфире информации общественно-значимой тематики о деятельности Законодательной Думы Томской области
# Pos [] Neg []
# 0 Выполнение работ по развитию государственной информационной системы области «Система образования Вологодской области» способом адаптации и установки программы для ЭВМ и передача права на ее использование
# Pos [] Neg []
# 0 Выполнение работ по развитию государственной информационной системы: комплексная информационная система «Мобильные сервисы Правительства Москвы» в части АИС «Мобильное приложение «Моя Москва» и поддержание ее работоспособности в 2023-2024 гг.
# Pos [] Neg []
# 0 Выполнение работ по развитию государственной информационной системы: комплексная информационная система «Мобильные сервисы Правительства Москвы» в части АИС «Мобильное приложение «Наш город» и поддержание ее работоспособности в 2023-2025 годах
# Pos [] Neg []
# 0 Выполнение работ по развитию и модернизации медицинской информационной системы Государственной информационной системы в сфере здравоохранения Саратовской области («МИС ГИСЗ СО») для обеспечения возможности информационного взаимодействия с Программным обеспечением «Система для поддержки принятия врачебных решений «Webiomed» способом установки и адаптации программ для ЭВМ для нужд министерства здравоохранения Саратовской области
# Pos [] Neg []
# 0 Выполнение работ по развитию и модернизации медицинской информационной системы Государственной информационной системы в сфере здравоохранения Саратовской области («МИС ГИСЗ СО») способом установки и адаптации программных компонентов (программ для ЭВМ) для обеспечения возможности информационного взаимодействия с «Автоматизированной информационной системой Учета программ реабилитации и абилитации (АИС УПРА)» для нужд министерства здравоохранения Саратовской области
# Pos [] Neg []
# 0 Выполнение работ по развитию и обеспечению бесперебойного функционирования аппаратно-программного комплекса мониторинга и анализа информационного пространства (АПК МАИП) и единой интегрированной системы управления данными (ЕИСУД) Московской городской Думы
# Pos [] Neg []
# 0 Выполнение работ по развитию и оказание услуг по сопровождению автоматизированной системы электронного документооборота в центральном аппарате и территориальных органах Росреестра
# Pos [] Neg []
# 0 Выполнение работ по развитию подсистем АС ЕСРН ЯО в части перевода предоставления государственных услуг в электронный вид, включая разработку интерактивных форм заявлений на ЕПГУ с использованием визуального конструктора услуг
# Pos [] Neg []
# 0 Выполнение работ по развитию подсистем АС ЕСРН ЯО для межведомственного электронного взаимодействия с федеральными государственными информационными системами
# Pos [] Neg []
# 0 выполнение работ по развитию подсистем РС ЕГИСЗ ЯО в части подключения и передачи данных в Государственный информационный ресурс воинского учета
# Pos [] Neg []
# 0 Выполнение работ по развитию подсистемы "Внутренний порталПФР" АИС ПФР-2
# Pos [] Neg []
# 0 Выполнение работ по развитию подсистемы "Туристические услуги и сертификаты" государственной информационной системы "Современное образование Ленинградской области"
# Pos [] Neg []
# 0 Выполнение работ по развитию региональной автоматизированной системы централизованного оповещения Оренбургской области созданной на платформе системы обеспечения вызова экстренных оперативных служб по единому номеру «112» Оренбургской области и модернизации данной платформы
# Pos [] Neg []
# 0 Выполнение работ по развитию региональной инфраструктуры электронного правительства Саратовской области в сфере градостроительства и землепользования
# Pos [] Neg []
# 0 Выполнение работ по развитию системы электронного архива архивно-библиотечного фонда ВДНХ
# Pos [] Neg []
# 0 Выполнение работ по развитию функциональных подсистем, контуров и информационных баз данных АИС «ЕСТР»
# Pos [] Neg []
# 0 Выполнение работ по разработке и адаптации баз данных информационной системы «Мобильное приложение для бизнес-процессов оказания услуг по техническому обслуживанию внутридомового газового оборудования на базе технологической платформы «1С:Предприятие 8»
# Pos [] Neg []
# 0 Выполнение работ по разработке и адаптации баз данных информационной системы «Учёт аварийных заявок на базе технологической платформы «1С:Предприятие 8»
# Pos [] Neg []
# 0 Выполнение работ по разработке и сопровождению средства подписи с использованием сертифицированного криптопровайдера КриптоПРО CSP
# Pos [] Neg []
# 0 Выполнение работ по разработке интеграционных механизмов программного продукта "АВЕРС: Управление лесным фондом ПРОФ" для взаимодействия с формами-концентраторами Единого портала государственных услуг
# Pos [] Neg []
# 0 Выполнение работ по разработке комплекта документов регламентирующих процессы создания, развития, ввода в эксплуатацию и обследования информационных систем с проведением обследования и пусконаладочных работ государственных информационных систем Пермского края
# Pos [] Neg []
# 0 Выполнение работ по разработке модуля централизованного сбора сведений об обнаружении, предупреждении и ликвидации последствий компьютерных атак, а также реагированию на компьютерные инциденты центра кибербезопасности по реагированию на компьютерные инциденты платформы «ГосТех»
# Pos [] Neg []
# 0 Выполнение работ по разработке проектно-сметной документации по объекту: «Прокладка волоконно-оптического кабеля для развития единой информационно-телекоммуникационной сети Правительства Калининградской области на участке: г. Калининград, ул. Геологическая, д. 1 – г. Калининград, ул. Больничная, д. 5 (ОГКУ «ГАКО»)»
# Pos [] Neg []
# 0 Выполнение работ по разработке проектно-сметной документации по объекту: «Прокладка волоконно-оптического кабеля для развития единой информационно-телекоммуникационной сети Правительства Калининградской области на участке: г. Калининград, ул. Дм. Донского, 7А – г. Калининград, ул. Комсомольская, д. 25 (ОМЦ «Резерв»)»
# Pos [] Neg []
# 0 Выполнение работ по разработке проектно-сметной документации по объекту: «Прокладка волоконно-оптического кабеля для развития единой информационно-телекоммуникационной сети Правительства Калининградской области на участке: г. Калининград, ул. Комсомольская, д. 25 – г. Калининград, ул. Комсомольская, д. 32 (ОГКУ «ГАКО»)»
# Pos [] Neg []
# 0 Выполнение работ по разработке технического проекта модернизации объединенной сетевой инфраструктуры Социального фонда России
# Pos [] Neg []
# 0 Выполнение работ по разработке, адаптации, модификации программ 1С: Предприятие
# Pos [] Neg []
# 0 Выполнение работ по содержанию комплексов АСУДД на автомобильных дорогах общего пользования регионального и межмуниципального значения, в том числе сбор, обработка, хранение и доставка информации до ситуационного центра Заказчика
# Pos [] Neg []
# 0 Выполнение работ по созданию виртуального тура «Промышленность Поморья»
# Pos [] Neg []
# 0 Выполнение работ по созданию единой информационной сети всего парка оборудования и рабочих мест АО «ПЗЦМ»
# Pos [] Neg []
# 0 Выполнение работ по созданию и внедрению обучающего тренажера геофизических исследований в рамках «Югра НГК Проф» (горнодобывающая отрасль) федерального проекта «Профессионалитет»
# Pos [] Neg []
# 0 Выполнение работ по созданию ИСУЭ в МКД (предусматривающего проектно-изыскательские работы, поставку оборудования, монтажные и пусконаладочные работы узлов учета электроэнергии у потребителей) для нужд АО «Чеченэнерго» (Заказчик, Организатор), управляемого ПАО «Россети Северный Кавказ».
# Pos [] Neg []
# 0 Выполнение работ по созданию комплекса программно-технических средств Координационного центра Оренбургской области
# Pos [] Neg []
# 0 Выполнение работ по созданию многофункционального узла безопасности
# Pos [] Neg []
# 0 Выполнение работ по созданию систем видеонаблюдения и контроля управления доступом для объектов филиалов АО "НОКК"
# Pos [] Neg []
# 0 Выполнение работ по технической доработке и сопровождению модуля ПК "СТАСУС-Поставщик", необходимого для осуществления мониторинга текущих цен строительных ресурсов
# Pos [] Neg []
# 0 Выполнение работ по техническому обслуживанию и ремонту средств вычислительной техники МИЦ СФР на технологической площадке № 2
# Pos [] Neg []
# 0 Выполнение работ по установке и настройке системы мониторинга информационной безопасности в администрации города Радужный
# Pos [] Neg []
# 0 Выполнение работ по установке и настройке системы мониторинга информационной безопасности в медицинских организациях Ханты-Мансийского автономного округа – Югры
# Pos [] Neg []
# 0 Выполнение работ по установке и настройке системы мониторинга информационной безопасности в медицинских организациях Ханты-Мансийского автономного округа – Югры
# Pos [] Neg []
# 0 Выполнение работ по установке и настройке системы мониторинга информационной безопасности в медицинских организациях Ханты-Мансийского автономного округа – Югры
# Pos [] Neg []
# 0 Выполнение работ по установке и пуско-наладке оборудования для региональной автоматизированной системы централизованного оповещения Сахалинской области
# Pos [] Neg []
# 0 Выполнение работ по установке обновлений ОС и приложений для слаженной работы структурных подразделений ГОБУЗ "МОПНД", установке и настройке нового оборудования и программных продуктов, созданию, поддержки и актуализации аккаунтов корпоративных пользователей, обслуживанию офисной оргтехники, телекоммуникационного и сетевого оборудования.
# Pos [] Neg []
# 0 Выполнение работ по установке обновлений ОС и приложений для слаженной работы структурных подразделений ГОБУЗ "МОПНД", установке и настройке нового оборудования и программных продуктов, созданию, поддержки и актуализации аккаунтов корпоративных пользователей, обслуживанию офисной оргтехники, телекоммуникационного и сетевого оборудования.
# Pos [] Neg []
# 0 Выполнение работ по эксплуатационно-техническому обслуживанию программно-аппаратного комплекса региональной автоматизированной системы централизованного оповещения
# Pos [] Neg []
# 0 Выполнение работ помонтажу,  инсталяции, настройке оборудования и программного обеспечения радиостудии
# Pos [] Neg []
# 0 Выполнение услуги по техническому обслуживанию КИПиА, технологических защит и программного обеспечения газотурбинных установок Taurus 60 ст.№№1,2,3,4 ГТУ-ТЭС г. Елабуга
# Pos [] Neg []
# 0 Выполнению работ по доработке существующих систем претензионно-исковой работы и исполнительного производства ГУП «ТЭК СПб» и СЭД ГУП «ТЭК СПб», а также существующих модулей для указанных систем
# Pos [] Neg []
# 0 Договор б/н
# Pos [] Neg []
# 0 договор о информационно-технологическом сопровождении системы "1С: Предприятие".
# Pos [] Neg []
# 0 Допоставка экземпляров в комплект Систем КонсультантПлюс и на оказание услуг по адаптации и сопровождению экземпляров Систем КонсультантПлюс на основе специального лицензионного программного обеспечения, обеспечивающего совместимость услуг с установленными у Заказчика экземплярами Систем КонсультантПлюс (в том числе специальной копии Систем КонсультантПлюс)
# Pos [] Neg []
# 0 Допоставка экземпляров в комплект Систем КонсультантПлюс и оказание услуг по адаптации и сопровождению экземпляров Систем КонсультантПлюс на основе специального лицензионного программного обеспечения, обеспечивающего совместимость услуг с установленными у Заказчика экземплярами Систем КонсультантПлюс (в том числе специальной копии Систем КонсультантПлюс).
# Pos [] Neg []
# 0 Допоставка экземпляров в комплект Систем КонсультантПлюс, а также оказание услуг по адаптации и сопровождению экземпляров систем КонсультантПлюс на основе специального лицензионного программного обеспечения, обеспечивающего совместимость дополнительных экземпляров и услуг с установленными у заказчика экземплярами Систем КонсультантПлюс для нужд СПб ГБУЗ "Городская стоматологическая поликлиника №3" в 2023-2024 годах
# Pos [] Neg []
# 0 Допоставка экземпляров в комплект Систем КонсультантПлюс, а также услуги по адаптации и сопровождению экземпляров Систем КонсультантПлюс, оказываемые на основе специального лицензионного программного обеспечения, обеспечивающего совместимость дополнительных экземпляров и услуг с установленными у заказчика экземплярами Систем КонсультантПлюс (в том числе специальной копией Системы КонсультантПлюс)
# Pos [] Neg []
# 0 Допоставка экземпляров в комплект Систем КонсультантПлюс, а также услуги по адаптации и сопровождению экземпляров Систем КонсультантПлюс, оказываемые на основе специального лицензионного сервисного программного обеспечения, обеспечивающего совместимость (взаимодействие) дополнительных экземпляров и услуг с ранее установленными у Заказчика экземплярами Систем КонсультантПлюс
# Pos [] Neg []
# 0 Доработка в программе «1С: Бухгалтерия государственного учреждения, ред. 2.0»
# Pos [] Neg []
# 0 доработка программы для ЭВМ "Паспорт здоровья авиационного персонала" и переход на актуальное российское программное обеспечение
# Pos [] Neg []
# 0 ЕК149-23  оказание консультационных услуг по сертификации медицинской организации в соответствии с моделью EMRAM HIMSS в части проведения консультаций при подготовке к валидации
# Pos [] Neg []
# 0 ЕК149-23  оказание консультационных услуг по сертификации медицинской организации в соответствии с моделью EMRAM HIMSS в части проведения консультаций при подготовке к валидации
# Pos [] Neg []
# 0 Заключение договора на оказание услуг по адаптации и сопровождению экземпляров Систем Консультант Плюс на основе специального лицензионного программного обеспечения, обеспечивающего совместимость услуг с установленными ранее экземплярами Систем Консультант Плюс
# Pos [] Neg []
# 0 Заключение договора на оказание услуг по сопровождению/технической поддержке системы управления проектами строительства для нужд ПАО «Россети Северный Кавказ» (Организатор, Заказчик).
# Pos [] Neg []
# 0 закупка в сфере ИКТ - сопровождение программного обеспечения 1с на 2025 год
# Pos [] Neg []
# 0 закупка в сфере ИКТ - сопровождение программного обеспечения на 2024 год
# Pos [] Neg []
# 0 Закупка лицензии простой (неисключительной) на продление прав использования Комплекса безопасности «Континент» Версия 4 и ключа активации сервиса технической поддержки
# Pos [] Neg []
# 0 Закупка лицензий (неисключительные права) на программное обеспечение «MedPoint».
# Pos [] Neg []
# 0 Закупка на 2023 год на оказание услуг по учёту автомобильных дорог и искусственных дорожных сооружений с составлением технического паспорта и формированием базы дорожных данных.
# Pos [] Neg []
# 0 Закупка программного комплекса "Гранд-смета"
# Pos [] Neg []
# 0 Закупка сертификата активации сервиса совместной технической поддержки продуктов ViPNet.
# Pos [] Neg []
# 0 закупка сетевого издания СПАРК
# Pos [] Neg []
# 0 Закупка товаров, работ и услуг в сфере информационно-коммуникационных технологий (оказание услуг по адаптации и сопровождению  экземпляров Систем КонсультантПлюс) для нужд  ФКУЗ "МСЧ МВД России по Владимирской области
# Pos [] Neg []
# 0 Закупка товаров, работ, услуг в сфере информационно-коммуникационных технологий (оказание услуг по адаптации и сопровождению экземпляров Специальных выпусков Систем семейства «КонсультантПлюс» на основе специального лицензионного программного обеспечения, обеспечивающего совместимость услуг с установленными у Государственного заказчика экземплярами Систем КонсультантПлюс)
# Pos [] Neg []
# 0 Закупка у единственного поставщика (подрядчика, исполнителя), участниками которой могут быть только субъекты малого и среднего предпринимательства на право оказания услуг по технической поддержке и сопровождению эксплуатации программно-технического комплекса "Криптобиокабина" и прикладного программного обеспечения "Криптобиокабина" (ПТК КБК и ППО КБК)
# Pos [] Neg []
# 0 Закупка у единственного поставщика (подрядчика, исполнителя), участниками которой могут быть только субъекты малого и среднего предпринимательства на право оказания услуг по технической поддержке программно-аппаратных комплексов телефонного обслуживания
# Pos [] Neg []
# 0 Закупка услуг по активации комплекта ключей технической поддержки для оборудования Континент
# Pos [] Neg []
# 0 Закупка услуг по предоставлению доступа к омниканальной платформе роботизации текстовых коммуникаций
# Pos [] Neg []
# 0 закупка услуг по сервисному обслуживанию программных средств системы "1С:Предприятие 8"
# Pos [] Neg []
# 0 Закупка услуг сопровождения в Системе
# Pos [] Neg []
# 0 Запрос котировок в электронной форме (№ ЦА 46-23) по выбору организации на оказание услуг по техническому сопровождению автоматизированной информационной системы кадрового учета и расчетов с персоналом на платформе «1С: ПРЕДПРИЯТИЕ 8.3» для нужд ФГУП «Росморпорт»
# Pos [] Neg []
# 0 Запрос котировок в электронной форме (далее-закупка) на право заключения договора на оказание услуг по Диагностике производительности и отказоустойчивости 1С ГВК-106
# Pos [] Neg []
# 0 Запрос котировок в электронной форме на право заключения Договора на оказание услуг по сопровождению Систем КонсультантПлюс
# Pos [] Neg []
# 0 Запрос котировок в электронной форме на предоставление неисключительного права на использование пакета дополнений для специализированного программного обеспечения подсистемы анализа и контроля защищенности автоматизированных систем.
# Pos [] Neg []
# 0 Запрос котировок в электронной форме среди субъектов малого и среднего предпринимательства на право заключения договора на поставку сертификатов полной технической поддержки программного обеспечения видео-конференц-связи TrueConf Server V.
# Pos [] Neg []
# 0 Запрос котировок в электронной форме, участниками которого могут быть только субъекты малого и среднего предпринимательства, (№ СФ 66 -23) по выбору организации на право заключения договора на оказание услуг по адаптации и сопровождению  справочно-правовых систем КонсультантПлюс для нужд  ФГУП «НИКИМП»
# Pos [] Neg []
# 0 Запрос котировок в электронной форме, участниками которого могут быть только субъекты малого и среднего предпринимательства, на оказание услуг по адаптации и сопровождению экземпляров справочной правовой системы
# Pos [] Neg []
# 0 Запрос котировок в электронной форме, участниками которого могут быть только субъекты малого и среднего предпринимательства, на оказание услуг по технической поддержке программного обеспечения
# Pos [] Neg []
# 0 Запрос котировок на оказание услуг по сервисному обслуживанию пакета программ Кабинет Переливания крови для нужд ГБУЗ «ГКБ им. В.В. Вересаева ДЗМ» в 2023-2024 гг.
# Pos [] Neg []
# 0 Запрос предложений в электронной форме на оказание услуг по технической поддержке и сопровождению модифицированного модуля «Зонтичное поручительство» на базе программы для ЭВМ «АИС НГС»
# Pos [] Neg []
# 0 Запрос предложений в электронной форме на право заключения договора оказания услуг по информационно-технологическому сопровождению программных продуктов системы «1С: Предприятие» на 2024 год
# Pos [] Neg []
# 0 зз-31079 - 2023 Оказание услуг по поставке и подготовке к опытно-рабочей эксплуатации (установке, модификации, переносу данных, тестированию, проведению силами сотрудников Заказчика выборочной опытной эксплуатации и переносу остатков) программных продуктов: "1С: Бухгалтерия государственного учреждения, ред. 2.0", "Конфигурация 1С-КАМИН:Зарплата для бюджетных учреждений. Версия 5.5" и "1С: Комбинат планового питания», версия 2.0".
# Pos [] Neg []
# 0 ЗК-0205/23 Поставка сертификатов активации
# Pos [] Neg []
# 0 ЗК-0208/23 Поставка сертификата активации технической поддержки средства защиты среды виртуализации от несанкционированного доступа
# Pos [] Neg []
# 0 ИКТ Приобретение неисключительных прав (лицензии) на использование антивирусного программного обеспечения
# Pos [] Neg []
# 0 Информационно-вычислительные услуги по сопровождению бухгалтерских программ
# Pos [] Neg []
# 0 Информационное и техническое сопровождение по вопросам эксплуатации модулей мониторинга, установленных на подвижные объекты и программного обеспечения системы спутникового мониторинга «Скаут»
# Pos [] Neg []
# 0 Информационное обслуживание программно-аппаратного комплекса "AutoSat"
# Pos [] Neg []
# 0 Информационное сопровождение экземпляров Справочной системы «Консультант Плюс», обеспечивающего совместимость информационных услуг с установленными в Акционерное общество «Сахатранснефтегаз» экземплярами систем «Консультант Плюс»
# Pos [] Neg []
# 0 информационно-консультационные услуги по сопровождению программного обеспечения "Парус-Бюджет" (в рамках ИКТ)
# Pos [] Neg []
# 0 Информационно-консультационные услуги по сопровождению программных продуктов фирмы «1С»
# Pos [] Neg []
# 0 Информационно-техническое обслуживание автоматизированной системы управления гостиничным комплексом объектов ГТЦ ПАО «Газпром» для нужд ООО "Свод Интернешнл" Д.У.
# Pos [] Neg []
# 0 Информационные услуги на основе систем "Консультант Плюс"
# Pos [] Neg []
# 0 Информационные услуги по предоставлению онлайн-доступа к системе нормативно-технической документации
# Pos [] Neg []
# 0 Информационные услуги по сопровождению и обновлению ранее установленной информационно-справочной системы "Техэксперт: базовые нормативные документы"
# Pos [] Neg []
# 0 Информационные услуги по сопровождению систем консультант плюс для нужд  ЦНИИП
# Pos [] Neg []
# 0 Информационные услуги с использованием экземпляров Систем (услуги по адаптации и сопровождению экземпляров Систем)
# Pos [] Neg []
# 0 Исполнитель обязуется по заданию Заказчика оказать Услуги по программному продукту на платформе "1С" согласно Заявкам, а Заказчик обязуется принять и оплатить эти Услуги.
# Pos [] Neg []
# 0 ИТС 1С:Музей
# Pos [] Neg []
# 0 КО №2771/КО (385/78/2023) - Предоставление прав на использование лицензионного программного обеспечения 1С для нужд ООО «Петербургтеплоэнерго»
# Pos [] Neg []
# 0 КО №7769 (G23P200872) - Выполнение проектно-изыскательских работ по объекту: «Модернизация структурированной кабельной системы КИВС и системы технологического электропитания на объектах ПАО «Мосэнерго» для нужд Публичное акционерное общество энергетики и электрификации "Мосэнерго"
# Pos [] Neg []
# 0 Комплекс работ восстановлению работоспособности существующего автоматизированного комплекса дозирования серии АСДГН 30 для обеззараживания питьевой воды товарным гипохлоритом натрия на ВЗУ 5, 6, а также модернизации программного обеспечения комплекса под операционную систему Windows 10 с последующими пуско-наладочными работами.
# Pos [] Neg []
# 0 Комплекс услуг по модификации информационной системы «Система межведомственного управления в сфере контроля и лицензирования» (далее – Система) и проведению аттестации Системы на соответствие требованиям о защите информации ограниченного доступа, не составляющей государственную тайну
# Pos [] Neg []
# 0 Комплексная подготовка и аттестация по требованиям безопасности информации серверного оборудования, предназначенного для подключения к Системе межведомственного электронного взаимодействия (СМЭВ)
# Pos [] Neg []
# 0 Комплексное сервисное обслуживание аппаратных средств системы АДИС оперативно диспетчерской службы для нужд ГБУЗ ПК "Сивинская ЦРБ"
# Pos [] Neg []
# 0 Комплексное сопровождение программных продуктов «1С: Бухгалтерия государственного учреждения 8» и "1С: Зарплата и кадры государственного учреждения " для нужд УМВД России по Ярославской области
# Pos [] Neg []
# 0 Комплексное техническое обслуживание корпоративной компьютерной сети, программного обеспечения и телефонии администрации (исполнительно-распорядительного органа) муниципального района «Ферзиковский район»  (Реестровый номер: 1388Э-13/23сб)
# Pos [] Neg []
# 0 Комплексное техническое обслуживание корпоративной компьютерной сети, программного обеспечения и телефонии администрации (исполнительно-распорядительного органа) муниципального района «Ферзиковский район»  (Реестровый номер: 1468Э-13/23сб)
# Pos [] Neg []
# 0 Комплект поддержки Информационно-технологического-сопровождения Медицина
# Pos [] Neg []
# 0 Комплект программного обеспечения для станков с ЧПУ
# Pos [] Neg []
# 0 Конкурс в электронной форме № 559-23/кн/эф по выбору Исполнителя на право заключения контракта на оказание услуг по модернизации программных продуктов на платформе 1С:Предприятие посредством создания и внедрения информационной системы автоматизации бизнес-процессов финансово-хозяйственной деятельности, а также по сопровождению созданной информационной системы  для нужд ФГАОУ ВО «Сибирский федеральный университет»
# Pos [] Neg []
# 0 Конкурс в электронной форме на оказание услуг по технической поддержке АИС ВКПУ
# Pos [] Neg []
# 0 Конкурс в электронной форме участниками которого могут быть только субъекты малого и среднего предпринимательства на право заключения договора на выполнение работ по разработке и методическому сопровождению решений системы менеджмента в программном продукте "Business Studio" в 2024-2025 годах
# Pos [] Neg []
# 0 Консультационно-технологическое сопровождение прикладной программы (ПП) в «1С: Зарплата и кадры государственного учреждения 8 ПРОФ»
# Pos [] Neg []
# 0 Консультационные услуги в рамках Семинара-тренинга «CoGIS 10: От подготовки картографического проекта в настольной ГИС до настройки веб-карты»
# Pos [] Neg []
# 0 Консультационные услуги и техническая поддержка
# Pos [] Neg []
# 0 Консультационные услуги по прикладному программному продукту "1С: Бухгалтерия государственного учреждения 8", "1С: Зарплата и Кадры 8"
# Pos [] Neg []
# 0 Консультационные услуги по программе поддержки сотрудников для Нижневартовской ГРЭС
# Pos [] Neg []
# 0 Консультационные услуги по теме "Составление сметной документации ресурсно-индексным методом с применением ПК "ГРАНД-Смета"
# Pos [] Neg []
# 0 купли продажи
# Pos [] Neg []
# 0 Лицензии программного обеспечения и выполнение работ по созданию и внедрению системы электронного документооборота на базе 1С: Документооборот
# Pos [] Neg []
# 0 Лицензия на использование модуля "Личный кабинет ЭДО" ПП Талисман SQL
# Pos [] Neg []
# 0 Лицензия на операционную систему Astra Linux
# Pos [] Neg []
# 0 Лицензия программного обеспечения "Эконом-Эксперт. Онлайн"
# Pos [] Neg []
# 0 Лот № 0501-ЭКСП ДИТ-2024-ДЭК ОКПД2 62.02.20.  Оказание услуг по администрированию и технической поддержке сети 15516 и 2330 в интересах филиала «Дальэнергосбыт» и аппарата управления, г. ВладивостокЛот № 0502-ЭКСП ДИТ-2024-ДЭК ОКПД2 62.02.20.  Оказание услуг по администрированию и технической поддержке сети 20266 в интересах филиала «Хабаровскэнергосбыт»Лот № 0503-ЭКСП ДИТ-2024-ДЭК ОКПД2 62.02.20. Оказание услуг по администрированию и технической поддержке сети 20273 в интересах филиала «Амурэнергосбыт» Амурская область
# Pos [] Neg []
# 0 Лот № 17301-ЭКСП ДИТ-2024-ЯЭ «ОКПД2 62.02.30.000 Оказание услуг по предоставлению доступа и сопровождению базы данных "Техэксперт:Премиум"»
# Pos [] Neg []
# 0 Лот № 207/23 права использования программ для ЭВМ или баз данных с предоставлением права на получение услуг технической поддержки для АО «НТЭК». (3412186)
# Pos [] Neg []
# 0 Медицинские информационные системы «Ариадна»
# Pos [] Neg []
# 0 Мероприятия по автоматизации работы министерства строительства Самарской области
# Pos [] Neg []
# 0 МИ №18591/МИ (224P100568) - Техническая поддержка и оптимизация режимов работы инверторных систем бесперебойного питания системы автоматического регулирования турбогенератора и системы автоматического регулирования питательного турбонасоса мощностью 10кВА энергоблоков №1, 3, 5. для нужд филиала ПАО "ОГК-2" - Ставропольская ГРЭС
# Pos [] Neg []
# 0 МИ №18614/МИ (224P100459) - Техническое обслуживание систем промышленного телевидения блока №10 для нужд филиала ПАО "ОГК-2" - Троицкая ГРЭС
# Pos [] Neg []
# 0 Модернизация и обеспечение третьей линии технической поддержки автоматизированной системы управления деятельностью исполнительных органов государственной власти Свердловской области
# Pos [] Neg []
# ...
# Pos [] Neg []
# 0 Оказание услуг доработке программного обеспечения «Ангел: Административная комиссия город Новороссийск» в части интеграции с МВД России посредством единой системы межведомственного электронного взаимодействия
# Pos [] Neg []
# 0 Оказание услуг по абонентскому обслуживанию программы ЭВМ на базе информационной бизнес-платформы ODANT «Информационная система управления программой проведения капитального ремонта многоквартирных домов Рязанской области»
# Pos [] Neg []
# 0 Оказание услуг по внедрению новых функциональных механизмов медицинской информационной системы медицинских организаций (Создание единого цифрового контура в здравоохранении на основе единой государственной информационной системы (ЕГИСЗ), модернизация цифрового контура в здравоохранении, 2023,  ГБУЗ  "Медицинский информационно-аналитический центр" министерства здравоохранения Краснодарского края, Краснодарский край); шифр регионального проекта Краснодарского края 00N7007100639
# Pos [] Neg []
# 0 Оказание услуг по техническому обслуживанию оборудования муниципальной системы оповещения и системы экстренного оповещения и информирования населения об угрозе возникновения или о возникновении чрезвычайной ситуации на территории муниципального образования городской округ город-курорт Сочи Краснодарского края
# Pos [] Neg []
# 0 Оказание услуг по сопровождению и эксплуатации информационной системы «Единая платформа сайтов органов власти Пермского края» (ЕПС ПК)
# Pos [] Neg []
# 0 Право заключения государственного контракта на поставку программного обеспечения межсетевого экранирования Ideco UTM или эквивалент с системой обнаружения вторжений для обеспечения задачи безопасного межсетевого взаимодействия, учета и контроля использования ресурсов глобальной сети Интернет на условиях простой (неисключительной) лицензии для нужд Министерства финансов Республики Татарстан
# Pos [] Neg []
# 0 Оказание услуг по передаче неисключительных прав (лицензии) на использование Программы для ЭВМ "АИС Культурный регион", а также её сопровождению и технической поддержке
# Pos [] Neg []
# 0 Техническая поддержка и сопровождение портала правовой информации
# Pos [] Neg []
# 0 Услуги по разработке системы информационного ресурса для информационного сопровождения ЗЛ на всех этапах оказания медицинской помощи
# Pos [] Neg []
# 0 Оказание услуг по предоставлению поп поставке и внедрению оборудования, средств защиты информации и проведению аттестационных испытаний объекта информатизации-государственной информационной системы обеспечения градостроительной деятельности Карачаево-Черкесской Республики
# Pos [] Neg []
# 0 ЭА-№-13889/23 «Выполнение работ по разработке программного обеспечения "СЭД-Агент"»
# Pos [] Neg []
# 0 Услуги по разработке и внедрению модели автоматизации ЦСО и управленческого документооборота учреждения для нужд ЛОГБУЗ "ДКБ"
# Pos [] Neg []
# 0 Оказание услуг по созданию аналитической системы для опроса населения и мониторинга результатов прохождения опроса
# Pos [] Neg []
# 0 Право заключения договора оказания услуг по техническому обслуживанию программ для ЭВМ «Формирование экспресс-протокола о достоверности и качестве данных системы мониторинга переходных режимов» (ФЭП), «Мониторинг функционирования устройств и комплексов системы мониторинга переходных режимов» (МФУК), «Формирование прогнозных диспетчерских графиков операционных зон диспетчерских центров АО «СО ЕЭС» (Электронный график), «Автоматическая система сбора информации от регистраторов СМПР в on-line режиме», «Автоматическая система сбора информации от регистраторов СМПР в филиалах АО «СО ЕЭС» в off-line режиме», «Отображение данных от регистраторов СМПР на рабочем месте технолога» (АС СИ СМПР) (3388197)
# Pos [] Neg []
# 1 101-2023 Оказание услуг по техническому сопровождению регионального сегмента единой государственной информационной системы в сфере здравоохранения Кабардино-Балкарской Республики
# Pos [] Neg []
# 1 1117-р Оказание услуги по миграции автоматизированной информационной системы организации процесса выдачи специальных разрешений на движение крупногабаритных и (или) тяжеловесных транспортных средств по автомобильным дорогам общего пользования регионального и межмуниципального значения Смоленской области на сервер автоматизированной системы весового и габаритного контроля на дорогах регионального и межмуниципального значения Смоленской области
# Pos [] Neg []
# 1 2023-10684 Выполнение работ по развитию (модернизации) функционала информационно-поисковой системы цифрового фонда пользования на документы архивного фонда Воронежской области: создание подсистемы платных архивных услуг
# Pos [] Neg []
# 1 № 23 - ЭА 2 - 640: услуги по сопровождению прикладного программного обеспечения информационной системы «Электронный детский сад»
# Pos [] Neg []
# 1 № 23 – ЭК 2 – 562: работы по модификации государственной информационной системы обеспечения градостроительной деятельности с функциями автоматизированной информационно-аналитической поддержки осуществления полномочий в области градостроительной деятельности и адаптированными возможностями региональной геоинформационной системы Липецкой области в части второй очереди интеграции с ГИСОГД РФ, расширения функциональности геоинформационной подсистемы и интеграции с ФГИС «Единая цифровая платформа «Национальная система пространственных данных» (6 этап)
# Pos [] Neg []
# 1 № 23-ЭА-101 Работы по адаптации автоматизированной информационной системы ОБУ «УМФЦ Липецкой области» для предоставления услуг Социального фонда Российской Федерации
# Pos [] Neg []
# 1 №06-Ед223 на оказание услуг по подключению биохимического анализатора к региональной лабораторной информационной системе
# Pos [] Neg []
# 1 Выполнение работ (оказание услуг) по доработке и поддержке CRM системы Битрикс24 Института общественных наук федерального государственного бюджетного образовательного учреждения высшего образования «Российская академия народного хозяйства и государственной службы при Президенте Российской Федерации»(73/223-ЭМ-23)
# Pos [] Neg []
# 1 Выполнение работ по корректировке электронной модели территориальной схемы в области обращения с отходами на территории Владимирской области.
# Pos [] Neg []
# 1 Выполнение работ по модернизации информационно-вычислительных и телекоммуникационных систем
# Pos [] Neg []
# 1 Выполнение работ по модернизации комплексов фотовидеофиксации нарушений Правил дорожного движения
# Pos [] Neg []
# 1 Выполнение работ по обеспечению функционирования и развитию государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан в части разработки портала общественных обсуждения
# Pos [] Neg []
# 1 Выполнение работ по обслуживанию медицинской информационной системы «Ариадна» ГОБУЗ «МОПНД»
# Pos [] Neg []
# 1 Выполнение работ по развитию (модернизации) государственной Информационной системы управления ресурсами медицинских организаций Тюменской области
# Pos [] Neg []
# 1 Выполнение работ по развитию государственной информационной системы «Прикладное программное обеспечение «Автоматизированная система  обработки информации»
# Pos [] Neg []
# 1 Выполнение работ по развитию и обеспечению бесперебойного функционирования  системы управления информацией Московской городской Думы
# Pos [] Neg []
# 1 Выполнение работ по развитию и обеспечению функционирования государственных информационных систем Роспатента
# Pos [] Neg []
# 1 Выполнение работ по созданию информационных систем и по предоставлению доступа к сервисам «Конструктор правовых документов» и «Интерактивный калькулятор» для пользователей сайта ГБУ «Малый бизнес Москвы» (среди СМП и СОНО)
# Pos [] Neg []
# 1 Закупка комплекса услуг по технической поддержке информационных технологий для нужд Администрации Одинцовского городского округа Московской области в 2023 году
# Pos [] Neg []
# 1 Закупка на оказание информационно-технологических услуг для нужд АО «Одинцовская теплосеть» в 2023-2024 гг.
# Pos [] Neg []
# 1 Комплексные IT услуги для нужд ООО «Щекинская ГРЭС»
# Pos [] Neg []
# 1 Многофункциональная справочно-экспертная система
# Pos [] Neg []
# 1 На оказание услуг по установке и сопровождению информационных баз для нормативного обеспечения деятельности химико-аналитической лаборатории
# Pos [] Neg []
# 1 Оказание услуг  по технической поддержке комплекса региональных информационных систем: - «Система межведомственного электронного взаимодействия Курской области»; - «Портал государственных и муниципальных услуг Курской области»; - «Система исполнения услуг Курской области»
# Pos [] Neg []
# 1 Оказание услуг на информационно-технологические услуги информационных централизованных систем ГК "Росатом"
# Pos [] Neg []
# 1 Оказание услуг по адаптации и сопровождению электронного периодического справочника (информационного продукта вычислительной техники) для органов исполнительной власти Краснодарского края, содержащего информацию о текущем состоянии законодательства Российской Федерации
# Pos [] Neg []
# 1 Оказание услуг по администрированию ППО «Регистр получателей социальных услуг» и ППО «Система долговременного ухода» входящих в состав государственной информационной системы Самарской области «Социальное обслуживание граждан»
# Pos [] Neg []
# 1 Оказание услуг по внедрению в организациях, подведомственных Департаменту здравоохранения города Москвы, модели централизации учетной деятельности сервиса «Система консолидированного управленческого учета» автоматизированной информационной системы города Москвы «Единая медицинская информационно-аналитическая система города Москвы» (2-я очередь)
# Pos [] Neg []
# 1 Оказание услуг по сопровождению компонента «Интеграционная шина системы здравоохранения Ханты-Мансийского автономного округа – Югры» государственной информационной системы «центральный узел регионального сегмента единой государственной информационной системы в сфере здравоохранения Ханты-Мансийского автономного округа – Югры»
# Pos [] Neg []
# 1 Оказание услуг по модернизации подсистемы мониторинга и управления транспортными средствами органов государственной власти государственной информационной системы «Региональная навигационно-информационная система Новосибирской области»
# Pos [] Neg []
# 1 Оказание услуг по комплексному сопровождению информационных систем и сервисов таможни
# Pos [] Neg []
# 1 Оказание услуг по сопровождению и эксплуатации государственной региональной информационной системы обеспечения градостроительной деятельности с функциями автоматизированной информационно-аналитической поддержки осуществления полномочий в области градостроительной деятельности Пермского края
# Pos [] Neg []
# 1 Оказание услуг по разработке программного обеспечения
# Pos [] Neg []
# 1 Оказание услуг по переносу сайта с wix.com для ГКУСО МО Семейный центр помощи семье и детям "Чеховский"
# Pos [] Neg []
# 1 Право заключения договора на предоставление лицензии на право использования программного обеспечения для развертывания системы виртуализации и сертификата на сервисное обслуживание для нужд ПАО «Россети Урал»
# Pos [] Neg []
# 1 Оказание услуг по информационно-техническому сопровождению автоматизированной информационной системы обеспечения градостроительной деятельности муниципального образования Алтайского района Алтайского края
# Pos [] Neg []
# 1 Оказание услуг по техническому сопровождению государственной информационной системы обеспечения градостроительной деятельности Саратовской области
# Pos [] Neg []
# 1 Услуги по проектированию и разработке информационных технологий для прикладных задач и тестированию программного обеспечения
# Pos [] Neg []
# 1 Оказание услуг по сопровождению и консультационной поддержке Государственной информационной системы обеспечения градостроительной деятельности Республики Башкортостан за четвертый квартал 2023
# Pos [] Neg []
# 1 Оказание услуг по модификации программного обеспечения Государственной информационной системы обеспечения градостроительной деятельности Республики Бурятия (ГИСОГД РБ) в части интеграции Системы с Единой информационной системой жилищного строительства (ЕИС ЖС)
# Pos [] Neg []
# 1 Оказание услуг по сопровождению государственной информационной системы обеспечения градостроительной деятельности Ханты-Мансийского автономного округа – Югры
# Pos [] Neg []
# 1 Развитие государственной информационной системы обеспечения градостроительной деятельности Ульяновской области
# Pos [] Neg []
# 1 Оказание услуг по разработке интерактивного программного обеспечения и мультимедийного наполнения фото- и видеоматериалами
# Pos [] Neg []
# 1 Оказание услуг по технической поддержке и сопровождению системы проведения общественных обсуждений по вопросам градостроительной деятельности на официальном сайте Администрации городского округа Самара
# Pos [] Neg []
# 1 Оказание услуг по разработке системы графической идентификации для обновления главной страницы портала «СтроимПросто»
# Pos [] Neg []
# 0 2024/9-14 Оказание услуг по мониторингу и реагированию на инциденты информационной безопасности для АО «Сетевая компания»
# Pos [] Neg []
# 0 208165_Выполнение работ по приведению системы обработки пакета документов для подготовки иска к сетевой организации в соответствие Методике МТ-259-1 АО «Мосэнергосбыт»
# Pos [] Neg []
# 0 23-101943 оказание услуг по доработке и технической поддержке  модулей «Архивный отдел» и «Реестр выдачи ордеров на производство земляных работ» для нужд Администрации города Челябинска
# Pos [] Neg []
# 0 А3-2/2023 выполнение работ по проведению аварийного восстановления данных, необходимых для стабильной работы, недопущению аварийных ситуаций и обеспечению возможности оперативного реагирования на технологические нарушения на объектах электросетевого хозяйства АО «МСК Энерго»
# Pos [] Neg []
# 0 В соответствии с описанием предмета закупки
# Pos [] Neg []
# 0 Выполнение работ по внедрению медицинского изделия с технологией искусственного интеллекта в Информационную систему управления ресурсами медицинских организаций Тюменской области Государственной информационной системы в сфере здравоохранения Тюменской области
# Pos [] Neg []
# 0 Выполнение работ по внедрению платформы роботизации Кузбасса и настройке роботизированных процессов
# Pos [] Neg []
# 0 Выполнение работ по внедрению программных интерфейсов для информационного взаимодействия ИС "Инфраструктура пространственных данных Приморского края" с ФГИС "Единая цифровая платформа Национальная система пространственных данных"
# Pos [] Neg []
# 0 Конкурс в электронной форме участниками которого могут быть только субъекты малого и среднего предпринимательства на право заключения договора на выполнение работ по развитию и поддержанию работоспособности системы мониторинга мобильных устройств в 2023 году
# Pos [] Neg []
# 0 Конкурс в электронной форме участниками которого могут быть только субъекты малого и среднего предпринимательства на право заключения договора на оказание услуг по сервисному обслуживанию системы видеонаблюдения на автотранспортной технике в 2024 году
# Pos [] Neg []
# 0 Модификация, адаптация и обновление автоматизированной информационной системы документооборота и делопроизводства
# Pos [] Neg []
# 0 Модификация, адаптация и обновление автоматизированной информационной системы документооборота и делопроизводства
# Pos [] Neg []
# 0 Оказание услуг в области информационных технологий
# Pos [] Neg []
# 0 Оказание услуг на базе центра обработки данных, включающих предоставление облачной инфраструктуры
# Pos [] Neg []
# 0 Оказание услуг по внедрению «Мобильного приложения для управления личным кабинетом абонента»
# Pos [] Neg []
# 0 Оказание услуг по внедрению новых сервисов на базе программного продукта «Медицинская Информационная Система «Комплекс Программных Средств «Система Автоматизации Медико-Страхового Обслуживания Населения» «САМСОН» (Далее МИС) в 2023 году для нужд СПб ГБУЗ «Городская больница №20»
# Pos [] Neg []
# 0 Оказание услуг по внедрению новых сервисов на базе программного продукта «Медицинская Информационная Система «Комплекс Программных Средств «Система Автоматизации Медико-Страхового Обслуживания Населения» «САМСОН» (Далее МИС) в 2023 году для нужд СПб ГБУЗ «Детская инфекционная больница №3»
# Pos [] Neg []
# 0 Услуги по созданию и внедрению информационной системы «Корпоративный портал» на основе Битрикс24
# Pos [] Neg []

# %%
df_keys = pd.read_csv('key_words.csv',delimiter=';')
keys = ['антивирус']
text = 'Программное средство антивирусной защиты'
text =  text.lower().strip() # переводим в нижний регистр
for k in keys:
    if len(l:=re.findall(k, text))>0:
        cnt[l[0]]=len(l)      

print(cnt)
# Out:
# {'антивирус': 1}

# %%
keys
# Out:
# ['континент',
#  'техническая поддержка',
#  'абонемент',
#  'доработка',
#  'защита (информации)',
#  'консультации',
#  'консультационные услуги',
#  'образование',
#  'образовательные услуги',
#  'глонасс',
#  '\\bgps\\b',
#  'бюджет',
#  'антивирус',
#  'контур контур контур',
#  '(?:\\bмис\\b|медицинская информационная система)',
#  'мис ариадна',
#  'техэксперт',
#  'бд супа',
#  'технокад',
#  'omnicommonline',
#  'карант',
#  'парус',
#  'континент',
#  'оборудование',
#  'лицензия',
#  'неисключительные права',
#  'аттестация',
#  'контур-фокус',
#  'сертификат',
#  'брест',
#  'vipnet',
#  'барс-здравоохранение',
#  'бит.управление медицинскими сервисами',
#  'autosat',
#  'varonis',
#  'гранд-смета',
#  'спарк',
#  'кодекс',
#  'иас контрагент',
#  'катарсис',
#  'статус-поставщик',
#  '\\brosa\\b',
#  'labforce',
#  'enterprize',
#  'vizualization',
#  'businessstudio',
#  'право использования']
